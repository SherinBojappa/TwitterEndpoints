# %% [markdown]
# # Listen For Important Events
#
# The goal of this tutorial is to introduce how to use the filtered stream and sample stream endpoints, more details can be found - [FilteredStream](https://developer.twitter.com/en/docs/twitter-api/tweets/filtered-stream/integrate/build-a-rule) <br>
# This code is based on [SampleCodeFilteredStream](https://github.com/twitterdev/Twitter-API-v2-sample-code/blob/main/Filtered-Stream/filtered_stream.py) repository. <br>

# %% [markdown]
# ## Import Required Modules

# %%
import requests
import os
import json

# %% [markdown]
# ## Environment Setup

# %% [markdown]
# - You would need to set up the bearer token, from your twitter App developer dashboard, for secure point of entry to use the twitter API.
# - The bearer token can be found on your twitter App developer dashboard under the "keys and tokens" page of the desired twitter app, for more details check out [BearerToken](https://developer.twitter.com/en/docs/authentication/oauth-2-0/bearer-tokens) <br>
# - A secure way to use your credentials is by creating environment variables in your terminal.
# ```console
# export 'BEARER_TOKEN'='xxxx'
# ```
# - bearer_oauth is used for bearer_token authorization.

# %%
bearer_token = os.environ.get("BEARER_TOKEN")

def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2FilteredStreamPython"
    return r

# %% [markdown]
# ## Sample Stream
#
# - You can use the sample stream endpoint to get 1% of all tweets happening on twitter.
# - Based on these tweets you can pick up trends and popular topics among them.
# - You can access the sample stream endpoint using create_url.
# - To get response from the end point you can use connect_to_endpoint

# %%
def create_url():
    return "https://api.twitter.com/2/tweets/sample/stream"

# %%
def connect_to_endpoint(url):
    response = requests.request("GET", url, auth=bearer_oauth, stream=True)
    print(response.status_code)
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            print(json.dumps(json_response, indent=4, sort_keys=True))
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )

# %% [markdown]
# ## Get 1% of All Activity on Twitter

# %%
url = create_url()
timeout = 0
while True:
    connect_to_endpoint(url)
    timeout += 1
# Out:
# 200
# {
#     "data": {
#         "id": "1508968329419108355",
#         "text": "\u0627\u0633\u062a\u063a\u0641\u0631 \u0627\u0644\u0644\u0647 \u0627\u0644\u0630\u064a \u0644\u0627 \u0625\u0644\u0647 \u0625\u0644\u0627 \u0647\u0648 \u0627\u0644\u062d\u064a \u0627\u0644\u0642\u064a\u0648\u0645 \u0648\u0623\u062a\u0648\u0628 \u0625\u0644\u064a\u0647"
#     }
# }
# {
#     "data": {
#         "id": "1508968329394139136",
#         "text": "RT @IAmNetcromancer: Congress gives themselves a generous 21% pay raise\n\nmeanwhile... the military are getting a mere 4.6% increase\n\nbut ye\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968329415118848",
#         "text": "\u3084\u30fc\u3070\u3044\n\u3068\u3093\u3060\u3068\u3093\u3060\u308f\n\u307e\u3093\u305b\u3048\n\ud83d\ude2d\ud83d\ude1d"
#     }
# }
# {
#     "data": {
#         "id": "1508968329402535937",
#         "text": "RT @jeremyaons: \u0e40\u0e19\u0e35\u0e48\u0e22\u0e22\u0e22\u0e22\u0e22\u0e22\u0e44\u0e21\u0e48\u0e43\u0e2b\u0e49\u0e23\u0e31\u0e01\u0e44\u0e14\u0e49\u0e44\u0e07 \u0e1e\u0e2d\u0e2e\u0e32\u0e23\u0e34\u0e23\u0e39\u0e49\u0e27\u0e48\u0e32\u0e17\u0e48\u0e32\u0e19\u0e1b\u0e23\u0e30\u0e18\u0e32\u0e19\u0e01\u0e25\u0e31\u0e27\u0e15\u0e2d\u0e19\u0e1d\u0e19\u0e15\u0e01 \u0e2e\u0e32\u0e23\u0e34\u0e40\u0e25\u0e22\u0e1e\u0e32\u0e40\u0e14\u0e15\u0e15\u0e32\u0e21\u0e23\u0e16\u0e44\u0e1f\u0e43\u0e15\u0e49\u0e14\u0e34\u0e19 \u0e21\u0e32\u0e19\u0e31\u0e48\u0e07\u0e02\u0e49\u0e32\u0e07\u0e46\u0e40\u0e1e\u0e37\u0e48\u0e2d\u0e44\u0e21\u0e48\u0e43\u0e2b\u0e49\u0e40\u0e2b\u0e47\u0e19\u0e15\u0e2d\u0e19\u0e1d\u0e19\u0e15\u0e01\ud83e\udd7a\ud83d\udc99\u0e21\u0e31\u0e19\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968329381306371",
#         "text": "@CxiYiv \n\u3054\u5fdc\u52df\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\uff01\n4/6\u307e\u3067\u4f7f\u3048\u308b\u300c\u30a6\u30c1\u30ab\u30d5\u30a7\u30b9\u30a4\u30fc\u30c4\u5404\u7a2e20\u5186\u5f15\u5238\u300d\u3092\u5dee\u3057\u4e0a\u3052\u307e\u3059\u3002\u307b\u3063\u3068\u3072\u3068\u606f\u306f\u30a6\u30c1\u30ab\u30d5\u30a7\u30b9\u30a4\u30fc\u30c4\u3067\u266a\u6b21\u56de\u3082\u30c1\u30e3\u30ec\u30f3\u30b8\u3057\u3066\u4e0b\u3055\u3044(^^)\n\u30af\u30fc\u30dd\u30f3\u306e\u4f7f\u3044\u65b9:https://t.co/jiWDM5AI9C #\u30ed\u30fc\u30bd\u30f3 https://t.co/N8U4ahyQIa"
#     }
# }
# {
#     "data": {
#         "id": "1508968329410662417",
#         "text": "$FLUX https://t.co/lg02bfXin4 https://t.co/idaEi6n34S"
#     }
# }
# {
#     "data": {
#         "id": "1508968329398173696",
#         "text": "RT @OccupyDemocrats: BREAKING NEWS: The Mayor of Kyiv, the Ukrainian capital, blasts FOX News hosts Tucker Carlson and Candace Owens for su\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968329402273794",
#         "text": "RT @amyallantdf: Hi!!!! Just want to send out some \ud83e\udd17\ud83e\udd17\ud83e\udd17HUGs! Been busy, w/mother-in law visit, her 1st time at new house\ud83d\ude01Saw bro-in law &amp; hi\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968329402273793",
#         "text": "RT @wani77790074: Faster than the official art https://t.co/QCXrWWZdnO"
#     }
# }
# {
#     "data": {
#         "id": "1508968329385586697",
#         "text": "RT @politicalblond: But\u2026 let\u2019s worry about a laptop and the email lady.\ud83d\ude44"
#     }
# }
# {
#     "data": {
#         "id": "1508968329385545732",
#         "text": "@flinnie https://t.co/GYWHTRZOcx"
#     }
# }
# {
#     "data": {
#         "id": "1508968329385750528",
#         "text": "RT @toro_seiza: \u3010\u5bfe\u5927\u4fb5\u5bc7\u9632\u4eba\u4f5c\u6226\u30fb\u5404\u9632\u885b\u30e9\u30a4\u30f3\u5b9f\u6cc1\u3011\n\u30b4\u30ea\u30e9\u5be9\u795e\u8005\u3063\u3087\u3043 https://t.co/Loz0pd7Fhs"
#     }
# }
# {
#     "data": {
#         "id": "1508968329389690881",
#         "text": "RT @bored_miss99: \u0645\u0646 \u0642\u0648\u0629 \u0627\u0644\u0628\u0624\u0633 \u0641\u064a \u0647\u0630\u0627 \u0627\u0644\u0645\u062c\u062a\u0645\u0639 : \u0625\u0638\u0647\u0627\u0631 \u0647\u0648\u064a\u062a\u0643 \u0645\u0645\u0643\u0646 \u064a\u0639\u0648\u062f \u0639\u0644\u064a\u0643 \u0628\u0627\u0644\u0636\u0631\u0631 \u0623\u0648 \u064a\u0646\u0647\u064a \u062d\u064a\u0627\u062a\u0643."
#     }
# }
# {
#     "data": {
#         "id": "1508968329381253120",
#         "text": "Srsly \ud83e\udd23\ud83d\ude02\ud83d\ude43\ud83d\ude09 https://t.co/wjgxqAFtKB"
#     }
# }
# {
#     "data": {
#         "id": "1508968329385750529",
#         "text": "RT @SuhoBr: (#OFICIAL) 30/03/2022 - SUHO em 'Grey Suit' - 2st mini \u00e1lbum \ud83d\udc54 Mood Sampler #2\n\n\ud83c\udfb6 2022.04.04 6PM (KST)\n\n#SUHO #\uc218\ud638 \n#GreySuit #S\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968329402273796",
#         "text": "RT @Leilaulu0416: \u0646\u0627\u062f\u064a\u0647\u060c \u0648\u0645\u0646 \u064a\u0631\u0628\u062a \u0639\u0644\u0649 \u0643\u062a\u0641\u0643 \u062f\n\nhttps://t.co/RdcgYhkDRg"
#     }
# }
# {
#     "data": {
#         "id": "1508968329394126848",
#         "text": "didn\u2019t know this exists until now \ud83d\ude2d https://t.co/Suid695dJc"
#     }
# }
# {
#     "data": {
#         "id": "1508968329389690892",
#         "text": "RT @bubbleboixxx05: Anyone have a seat for me? \ud83d\ude08\ud83d\ude09 https://t.co/Xku1fykPDM"
#     }
# }
# {
#     "data": {
#         "id": "1508968329410912256",
#         "text": "RT @STV_FF: \ud83d\udcfa4\u67082\u65e5(\u571f)\u5915\u65b95\u664230\u5206\u30b9\u30bf\u30fc\u30c8\u203c\ufe0f\n\ud83c\udd95\u300e#\u30e9\u30d6\u30aa\u30fc\u30eb\u30d7\u30ec\u30fc\u300f\ud83c\udff8\n\n\u653e\u9001\u958b\u59cb\u2728\u3092\u8a18\u5ff5\u3057\u3066\n#\u30af\u30aa\u30ab\u30fc\u30c9 \u3092\ud83d\udd1f\u540d\u306b\u30d7\u30ec\u30bc\u30f3\u30c8\ud83c\udf81\n\n\u3010\u5fdc\u52df\u65b9\u6cd5\u3011\n1\u20e3\u3053\u306e\u30a2\u30ab\u30a6\u30f3\u30c8\u3092\u30d5\u30a9\u30ed\u30fc\n2\u20e3\u3053\u306e\u30c4\u30a4\u30fc\u30c8\u3092RT\n\ud83d\uddd3\ufe0f4\u67083\u65e5(\u65e5)\u7de0\u5207\n\ud83d\udce9\u5f53\u9078\u9023\u7d61\u306fDM\n\n\u4e3b\u4eba\u516c\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968329406554113",
#         "text": "RT @raq_stylesFcs: A fome \u00e9 algo que n\u00e3o d\u00f3i muito ! \ud83d\ude2d\ud83d\ude2d\ud83d\ude2d\nMoro sozinha em uma kitnet ,fiquei desempregada e para pagar meus alugu\u00e9is atrasad\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968329389563904",
#         "text": "@rkigram gm ean &lt;3"
#     }
# }
# {
#     "data": {
#         "id": "1508968329381236741",
#         "text": "RT @RVStatsBase: \"Feel My Rhythm\" surpassed 10M streams on spotify! \ud83c\udf89\n\n#RedVelvet @RVsmtown https://t.co/vxBaWmXEqZ"
#     }
# }
# {
#     "data": {
#         "id": "1508968329406386176",
#         "text": "RT @Sanjeev82331986: Tweeter pe upasthit sabhi rashtrawadi aur hindutivuvadi dosto ko subh prabhat Jai shree ganesh jai shree ram dosto dos\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968329406746626",
#         "text": "RT @khunMiniiwmoney: \u0e04\u0e19\u0e44\u0e17\u0e22\u0e21\u0e31\u0e19\u0e17\u0e33\u0e44\u0e21\u0e2d\u0e38\u0e1a\u0e32\u0e14\u0e43\u0e2a\u0e48\u0e40\u0e21\u0e19\u0e01\u0e39\u0e08\u0e31\u0e07"
#     }
# }
# {
#     "data": {
#         "id": "1508968329389625344",
#         "text": "RT @yaaaseeee: THIS SCENE BRO\u2026\u2026\u2026 https://t.co/0K56QDcwkT"
#     }
# }
# {
#     "data": {
#         "id": "1508968329381175299",
#         "text": "RT @19981013justice: \u75b2\u308c\u305f\u3089\u4f11\u3093\u3067\u3044\u3044\u304b\u3089\ud83d\ude0c\u2728\u2728\n\n@official__INI #INI \n#CALL119 / WeAre / AMAZE ME / BOMBARDA / DILEMMA / Polaroid / Rocketeer"
#     }
# }
# {
#     "data": {
#         "id": "1508968329414905856",
#         "text": "@ilenagm It was!"
#     }
# }
# {
#     "data": {
#         "id": "1508968329381179392",
#         "text": "Hati hati dengan warna itu., barangkali buka hanya aku yg menandai!! Semua orang, perasaanku."
#     }
# }
# {
#     "data": {
#         "id": "1508968329385431040",
#         "text": "likeame la historia y te agrego a \ud83d\udd12mj"
#     }
# }
# {
#     "data": {
#         "id": "1508968329389932544",
#         "text": "RT @DikelS: @manjos Tudo isto come\u00e7a logo mal quando se diz que a R\u00fassia \u00e9 uma democracia \ud83e\udd14, apartir daqui nada poder\u00e1 bater certo."
#     }
# }
# {
#     "data": {
#         "id": "1508968329406730240",
#         "text": "RT @aremmd: boo blue  //  pls rt \u2018 fav \u270d\ud83c\udffb\n\n\ud83c\udfc3\u200d\u2640\ufe0f\ud83e\ude74 \u05af  \ud80c\udc82            \ud83d\udc0b \ud83c\udfdd \ud83c\udfca\ud83c\udffb\u200d\u2642\ufe0f\n\n\ud83d\udeb4\ud83c\udffb\u200d\u2642\ufe0f\ud83d\udcd8\ud83d\udd87             \ud83d\udd17\ud83e\uded0\ud83e\udee7\n\n\ud80c\udef0 \ud83c\udf76\ud83d\udedd             \ud83d\udef4\ud83e\uddf5\ud83d\udebf\n\n[  #\u0e41\u0e08\u0e01\u0e2d\u0e34\u0e42\u0e21\u0e08\u0e34 #\u0e41\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968329398337536",
#         "text": "@shishimaru_GoGo \u3057\u3057\u307e\u308b\u3055\u3093\n\u3053\u3093\u306b\u3061\u306f\u2728\ud83d\ude03\u2757\n\n\u7d20\u6575\u306a\u685c\ud83c\udf38\u3092\u3042\u308a\u304c\u3068\u3046\ud83c\udf80\n\n\u4eca\u65e5\u3082\u3088\u308d\u3057\u304f\u306d\ud83d\ude03\ud83c\udf52\ud83d\ude03"
#     }
# }
# {
#     "data": {
#         "id": "1508968329406402560",
#         "text": "RT @doyamaru_sps1: \uff0f\n\ud83c\udf08100\u540d\u69d8\u306b1,000\u5186\u5206\u306e\ud83c\udf08\n\u3010QUO\u30ab\u30fc\u30c9 Pay\u3011\u304c\n\u305d\u306e\u5834\u3067\u5f53\u305f\u308b\u203c\ufe0f\n\uff3c\n\n3\u670831\u65e5\u307e\u3067\u6bce\u65e5\u5fdc\u52df\ud83c\udd97\ud83d\ude46\u200d\u2642\ufe0f\n\n\u3010\u53c2\u52a0\u65b9\u6cd5\u3011\n1\ufe0f\u20e3@doyamaru_sps1\u3092\u30d5\u30a9\u30ed\u30fc\n2\ufe0f\u20e3\u3053\u306e\u6295\u7a3f\u30923\u670831\u65e59:59\u8fc4\u306bRT\n\u203b\u5f15\u7528R\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968329415135232",
#         "text": "RT @taihennna4649: \u8d85\u5d50\u3092\u547c\u3076\uff01\u9032\u6483\u306e\u5de8\u4eba https://t.co/D5j1fA4nLM"
#     }
# }
# {
#     "data": {
#         "id": "1508968333592473603",
#         "text": "RT @reescrevi_frase: \u201cvc parece triste oq vc tem?\u201d pensamentos"
#     }
# }
# {
#     "data": {
#         "id": "1508968333596672004",
#         "text": "RT @KeeleyFox29: WATCH:  BRAZEN catalytic converter creeps hit in heart of South Philly in DAYTIME, Tasker Street, b/t 2nd &amp; Moyemensing, W\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968333575700480",
#         "text": "Est\u00e1s si son buenas noticias \u2764\ud83d\ude2d\nMi lindo \u00e1ngel se recuper\u00f3 \n\nWE LOVE YOU HOBI\n#SeeYouSoonHobi https://t.co/eaCTHPDQdI"
#     }
# }
# {
#     "data": {
#         "id": "1508968333613441024",
#         "text": "RT @yemargent: \u00ab\u00a0C\u2019est de \u00e7a qu\u2019il s\u2019agit\u00a0\u00bb  la nouvelle phrase des bordelles"
#     }
# }
# {
#     "data": {
#         "id": "1508968333609033729",
#         "text": "RT @aminovital_jp: #\u30ac\u30c3\u30c4\u30ae\u30a2 \u26a1 #\u30a4\u30ca\u30ba\u30de\u30a4\u30ec\u30d6\u30f3 \u26bd\ufe0f\n\u30aa\u30ea\u30b8\u30ca\u30eb\u58c1\u7d19\u30d7\u30ec\u30bc\u30f3\u30c8\n\n\u7b2c\u4e00\u5f3e\u306f\u3001\u592a\u967d\u306b\u9078\u3070\u308c\u305f\u30b5\u30c3\u30ab\u30fc\u5c0f\u50e7 #\u7a32\u68ee\u660e\u65e5\u4eba\n\u4fdd\u5b58\u3057\u3066\u4f7f\u3063\u3066\u306d\uff01\n\n#\u30ac\u30c3\u30c4\u30ae\u30a2\u3067\u30b9\u30bf\u30fc\u30c8\u30c0\u30c3\u30b7\u30e5 \u30ad\u30e3\u30f3\u30da\u30fc\u30f3\u5b9f\u65bd\u4e2d\nhttps://t.co/gHiB7uU8\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968329381359621",
#         "text": "Entering my Holden Caulfield era, I\u2019ve heard enough out of you fakes and phonies \ud83c\udf3e"
#     }
# }
# {
#     "data": {
#         "id": "1508968333609037824",
#         "text": "RT @Constrictorz: YES HNNNGH https://t.co/K4YMgSRFjK"
#     }
# }
# {
#     "data": {
#         "id": "1508968333575553024",
#         "text": "RT @BBokkiiiii_: \uc7a1 \ud314\uc5d0 \ub9c8\uc2a4\ud06c\ub07c\uace0\uc787\ub294\uac70 \uac1c\uc6c3\uaca8 \ub098\uc778\uc904 https://t.co/esWuiFPAga"
#     }
# }
# {
#     "data": {
#         "id": "1508968333609078786",
#         "text": "Watch full and retweet \ud83d\udca5\n\n#KGFChapter2 #KGFChapter2Trailer #KGF2onApr14 #YashBOSS #YashBOSS\ud80c\udcf5 #KGFVERSE #KGFFandom https://t.co/XahSoIDbqt"
#     }
# }
# {
#     "data": {
#         "id": "1508968333579804672",
#         "text": "@BritterDD https://t.co/wy4R6rWL6P"
#     }
# }
# {
#     "data": {
#         "id": "1508968333579673603",
#         "text": "https://t.co/JF3el7vC05"
#     }
# }
# {
#     "data": {
#         "id": "1508968333588463616",
#         "text": "RT @torutoridamari: \u3053\u306e3\u65e5\u5f8c\u3001\u4ea1\u304f\u306a\u3089\u308c\u305f\u3068\u306e\u3053\u3068\u3002\u6b7b\u56e0\u306f\u8133\u6897\u585e\u3060\u305d\u3046\u3067\u3059\u3002\u3053\u308c\u3067\u3082\u3001\u56e0\u679c\u95a2\u4fc2\u306f\u8a8d\u3081\u3089\u308c\u306a\u3044\u306e\u3060\u308d\u3046\u304b\u3002\u3002\u3002\n\n\u3054\u672c\u4eba\u69d8\u306e\u3054\u51a5\u798f\u3092\u7948\u308a\u3001\u3054\u5bb6\u65cf\u306b\u304a\u6094\u3084\u307f\u7533\u3057\u4e0a\u3052\u307e\u3059\u3002"
#     }
# }
# {
#     "data": {
#         "id": "1508968333613404162",
#         "text": "Expliquenme, ense\u00f1enmeeee, como hacen esas mujeres para vivir el d\u00eda form\u00e1ndole peos a la pareja \ud83d\ude02  yo no puedo, lo intento, pero no puedooooo"
#     }
# }
# {
#     "data": {
#         "id": "1508968333609033731",
#         "text": "RT @MaryJan43680470: Happy president day \ud83c\udf89 https://t.co/as8E7skExu"
#     }
# }
# {
#     "data": {
#         "id": "1508968333584265217",
#         "text": "RT @cloudgemz: $300 | 4.200.000 IDR | 72 Hours\n\n\u2601\ufe0f $150 - RT + Follow @AstronotsETH \n\n \ud83d\udcab BONUS $150 - Join Discord (+Proof)\n\nhttps://t.co/x\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968333601013761",
#         "text": "Matua Dharma Maha Mela 2022: PM Modi recalls his visit to Bangladesh's Orakandi Thakurbari\n https://t.co/6JR4IOAsf5\n\nvia NaMo App https://t.co/XdrbELM2JN"
#     }
# }
# {
#     "data": {
#         "id": "1508968333575483395",
#         "text": "RT @yanyan10131019: We Are \u30b7\u30a7\u30a2\u30ea\u30ec\u30fc\u53d7\u3051\u53d6\u308a\u307e\u3057\u305f\uff01\ud83d\ude0a\u304a\u6b21\u3069\u3046\u305e\u30fc\n\n#Spotify_INI\n#INI @official__INI #CALL119 / We Are / AMAZE ME / BOMBARDA / DILEMMA / Pola\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968333600821252",
#         "text": "RT @BANGT4NBEST: \u203c\ufe0fDIFUNDIR\u203c\ufe0f\n\nLa sp de hoy es enfocada en Suga se pueden unir a cualquier hora del d\u00eda porque no hay horarios es muy impor\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968333580042241",
#         "text": "@Moyashi_CODM \u3044\u3084\u3001\u5012\u3055\u308c\u305f\u6642\u306b\u306a\u308b\u8868\u793a\u306e\u3053\u3068"
#     }
# }
# {
#     "data": {
#         "id": "1508968333580042243",
#         "text": "RT @osakaigo: \u5c06\u68cb\u540d\u4eba\u306e\u6e21\u8fba\u660e\u301d\u30a2\u30de\u56f2\u7881\u4e09\u6bb5\u301f\u8a95\u751f\u3000\u65e5\u672c\u68cb\u9662\u306e\u5c0f\u6797\u899a\u7406\u4e8b\u9577\u304b\u3089\u514d\u72b6\uff1d\u6751\u4e0a\u8015\u53f8\u64ae\u5f71 https://t.co/5wKhhdRlbT @YouTube\u3088\u308a"
#     }
# }
# {
#     "data": {
#         "id": "1508968333588062211",
#         "text": "People who's trying to say in my face that they are way better than me in anything-- Oh! I wasn't informed that I was supposed to be someone like you. Sorry to say that I don't wanna be like you. Just do your own thing. I even support you with that. I've worked harder to be me."
#     }
# }
# {
#     "data": {
#         "id": "1508968333613449226",
#         "text": "RT @clarkkentxw: after my 2am workout https://t.co/M9ovHM1lKn"
#     }
# }
# {
#     "data": {
#         "id": "1508968333592436736",
#         "text": "@courtenaytaylor Got Thane. I'm very okay with this \ud83d\ude01\u2665\ufe0f"
#     }
# }
# {
#     "data": {
#         "id": "1508968333613301766",
#         "text": "RT @TheGloryPlanet: \ud83d\udce3Announcing our partnership with @_metadex. The collaboration will allow us to offer Metadex\u2019s algorithm-oriented DEX s\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968337778348035",
#         "text": "@jj2jjj2 @liiil7_"
#     }
# }
# {
#     "data": {
#         "id": "1508968337769910278",
#         "text": "RT @Emilybricks17: It's a special birthday for His Excellency Nana Addo .\n\nWorld Cup Qualified\ud83c\udfc6 \nE-Levy For Development Passed\nFirst Interc\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968337807577088",
#         "text": "@ConanOBrien Mac n me clip forever!! Love it!!!"
#     }
# }
# {
#     "data": {
#         "id": "1508968337769910279",
#         "text": "Not even gonna lie, I probably would. That\u2019s his problem, not mine \ud83d\ude02 https://t.co/I0hQ2oTgSL"
#     }
# }
# {
#     "data": {
#         "id": "1508968337770172421",
#         "text": "RT @sof1azara03: $100 or 1,4jt  Giveaway || 12hrs \ud83c\udf49\n\nRT + Like, RT &amp; Tag friends on the tweet below:\n\nhttps://t.co/6KNkDRF01f"
#     }
# }
# {
#     "data": {
#         "id": "1508968337807912964",
#         "text": "RT @potaelatte: \u0e2a\u0e48\u0e27\u0e19\u0e43\u0e04\u0e23\u0e17\u0e35\u0e48\u0e2d\u0e22\u0e32\u0e01\u0e43\u0e0a\u0e49 keycaps \u0e1b\u0e23\u0e30\u0e40\u0e20\u0e17\u0e2d\u0e37\u0e48\u0e19\u0e19\u0e2d\u0e01\u0e08\u0e32\u0e01 xda \u0e25\u0e2d\u0e07\u0e28\u0e36\u0e01\u0e29\u0e32\u0e41\u0e25\u0e30\u0e40\u0e25\u0e37\u0e2d\u0e01\u0e17\u0e23\u0e07 keycaps \u0e17\u0e35\u0e48\u0e0a\u0e2d\u0e1a\u0e15\u0e32\u0e21\u0e23\u0e39\u0e1b\u0e14\u0e49\u0e32\u0e19\u0e25\u0e48\u0e32\u0e07\u0e40\u0e25\u0e22\u0e04\u0e48\u0e30 https://t.co/CfZaMFug\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968337774157827",
#         "text": "RT @SinLinea_Mx: \u00bfD\u00f3nde las venden? \ud83d\ude02\nNuestra oposici\u00f3n es una mala broma \ud83d\udc47 https://t.co/8xbiw8V6jR"
#     }
# }
# {
#     "data": {
#         "id": "1508968337782751233",
#         "text": "RT @DitzyFlama: what if it was all a dream? https://t.co/i9oL1bXhpx"
#     }
# }
# {
#     "data": {
#         "id": "1508968337782579201",
#         "text": "RT @ParisDaguerre: Sickening that Johnson is throwing a party for all Tory MPs tonight in a central London hotel. The night when we know fo\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968337799360516",
#         "text": "RT @K3_M_J2_P: @AdrianaArmyM1 SI ERES MI PER\u00da QUERIDO, MI PA\u00cdS BENDITO QUE ME VIO NACER"
#     }
# }
# {
#     "data": {
#         "id": "1508968337786785792",
#         "text": "@HouseGOP @RepLarryBucshon https://t.co/u4gAwJw5fY"
#     }
# }
# {
#     "data": {
#         "id": "1508968337799512064",
#         "text": "RT @SABENZZ: \u0e40\u0e0b\u0e1f\u0e42\u0e0b\u0e19\u0e17\u0e35\u0e48\u0e14\u0e35\u0e17\u0e35\u0e48\u0e2a\u0e38\u0e14\u0e04\u0e37\u0e2d\u0e01\u0e32\u0e23\u0e19\u0e2d\u0e19\u0e40\u0e25\u0e48\u0e19\u0e42\u0e17\u0e23\u0e28\u0e31\u0e1e\u0e17\u0e4c\u0e17\u0e31\u0e49\u0e07\u0e27\u0e31\u0e19"
#     }
# }
# {
#     "data": {
#         "id": "1508968337786736646",
#         "text": "Lo apoyar\u00eda totalmente! https://t.co/5jaNokkyUa"
#     }
# }
# {
#     "data": {
#         "id": "1508968337774108676",
#         "text": "RT @ChantalMachabee: Joel Edmundson a dit la semaine derni\u00e8re que le prochain but qu'il marquerait serait en m\u00e9moire de son Papa. \ud83d\ude4f\u2764\ufe0f #GoHa\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968337782587397",
#         "text": "RT @JornalDaCidadeO: AO VIVO: Silveira enfrenta Moraes / O fim do caso Carvajal? (veja o v\u00eddeo) https://t.co/eAXT5nrRjv"
#     }
# }
# {
#     "data": {
#         "id": "1508968337782542337",
#         "text": "RT @abadon_AEW: Devil Grin \ud83d\ude08 https://t.co/vcunySXJuM"
#     }
# }
# {
#     "data": {
#         "id": "1508968337774362624",
#         "text": "RT @Ws__h_d: #\u5275\u4f5c\u767e\u5408\n\u4eba\u524d\u3067\u3081\u3063\u3061\u3083\u30d9\u30bf\u30d9\u30bf\u3057\u3066\u308b\u767e\u5408\u55b6\u696d\u30a2\u30a4\u30c9\u30eb\u3001\u64ae\u5f71\u7d42\u308f\u3063\u305f\u3089\u5373\u96e2\u308c\u3066\u3066\u6b32\u3057\u3044\u3057\u7247\u65b9\u306f\u672c\u6c17\u3067\u604b\u3057\u3066\u3066\u6b32\u3057\u3044 https://t.co/wFX01jcOpR"
#     }
# }
# {
#     "data": {
#         "id": "1508968337807593473",
#         "text": "RT @akirosenthal: \u304a\u3064\u305f\u30fc\u308b\ud83c\udf4e\n\u3082\u3082\u30af\u30ed\u3061\u3083\u3093\u30ea\u30b9\u30da\u30af\u30c8\u97f3\u982d\u3068\u53e3\u4e0a\u307f\u3093\u306a\u306e\u529b\u3092\u5408\u308f\u305b\u3066\u306a\u3093\u3068\u304b\u3067\u304d\u307e\u3057\u305f\u30fb\u30fb\u30fb\u30fb\u30fb\u30fb\u30fb\u30fb\uff01\uff01\n\n\u660e\u65e5\u63a8\u3057\u3092\u76ee\u306e\u524d\u306b\u3057\u3066\u51fa\u305b\u308b\u304b\u306f\u3002\u3002\u3002\u3002\n\u307e\u3060\u308f\u304b\u3089\u306a\u3044\uff57\uff57\uff57\uff57\uff57\uff57\uff57\n\n\u307f\u3093\u306a\u3042\u308a\u304c\u3068\u3046\ud83d\udc95\n#\u30a2\u30ad\u3073\u3085\u30fc\u308f\u30fc\u308b\u3069"
#     }
# }
# {
#     "data": {
#         "id": "1508968337790877699",
#         "text": "@grrwyz HELLO !!!!"
#     }
# }
# {
#     "data": {
#         "id": "1508968337807589379",
#         "text": "Padre: Rochu, pod\u00e9s hacer algo para comer? \nYo: no, estoy trabajando\nP: dale que no tengo ganas de cocinar\nY: estuve hasta las manos todo el d\u00eda y reci\u00e9n me puedo sentar a trabajar\nP: es que tengo ganas de ver la tele y ya trabaje todo el d\u00eda \n\n.....,.......... Se\u00f1or por favor"
#     }
# }
# {
#     "data": {
#         "id": "1508968329389789194",
#         "text": "@HelenaA84661222 #EuapoioDanielSilveira\nHelena a tag correta https://t.co/dMEv2a9f6Z"
#     }
# }
# {
#     "data": {
#         "id": "1508968337803743232",
#         "text": "@guro4ever54 \ucac0\uc544\uc560\uc694 ~~!"
#     }
# }
# {
#     "data": {
#         "id": "1508968337807912965",
#         "text": "@saihana_tea \u5148\u65e5\u3055\u3044\u3061\u3083\u3093\u306e\u8a71\u805e\u3044\u3066\u3001\u79c1\u3082\u5b50\u3069\u3082\u306b\u5168\u90e8\u9078\u3093\u3067\u3082\u3089\u304a\u3046\u3068\u601d\u3044\u307e\u3057\u305f\uff01\u8fd1\u6240\u306e\u9ad8\u5b66\u5e74\u306e\u5973\u5b50\u304c\u7d3a\u3068\u304b\u8336\u8272\u306e\u30ab\u30d0\u30fc\u4ed8\u3051\u3066\u305f\u306e\u3082\u7d0d\u5f97\u3002\u597d\u307f\u306f\u5909\u308f\u308b\u3088\u306d\ud83c\udf92"
#     }
# }
# {
#     "data": {
#         "id": "1508968337770000386",
#         "text": "RT @sigagalatas: Gratid\u00e3o a Deus por mais um dia \ud83e\udd0d"
#     }
# }
# {
#     "data": {
#         "id": "1508968337782579204",
#         "text": "RT @Kurban__Guler: evvel #alsancak 32 olan \u015feyleri https://t.co/oMGRkDAeyn"
#     }
# }
# {
#     "data": {
#         "id": "1508968337799319559",
#         "text": "@telepathyksj I need a surgery for colon cancer the surgery is expensive, we are asking for please help so we can pay for all the treatments to save my life. We sincerely appreciate any donation\ud83d\ude4f\ud83c\udffb\ud83e\udd7a\ud83d\ude4f\ud83c\udffbplease donate in my airfunding it's urgent\ud83c\udd98 \nhttps://t.co/F0o97nBICt https://t.co/8z5wihbUNR"
#     }
# }
# {
#     "data": {
#         "id": "1508968337782427652",
#         "text": "RT @RepChipRoy: Rep. Roy has been calling for Mayorkas' impeachment for months, and he\u2019s now urging ALL Republicans to join him:\n\nhttps://t\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968337769857024",
#         "text": "RT @sxxghoon: \ud83c\udd70\ufe0f\ud83c\udd70\ufe0f\ud83c\udd70\ufe0f\ud83c\udd70\ufe0f\ud83c\udd70\ufe0f\ud83d\ude2d\ud83d\ude2d\ud83d\ude2d\n\nGuyss karena aku seneng banget22 dapet tiket justin, aku mau giveaway 100k untuk 1 orang. Syaratnya rt, like a\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968337782767616",
#         "text": "@lidangzzz \u6b7b\u4e86\u51e0\u767e\u4e07\u4eba\u3002\u3002\u4e0d\u77e5\u9053\u8c01\u662f\u7b11\u8bdd\uff0c\u5478"
#     }
# }
# {
#     "data": {
#         "id": "1508968337782583299",
#         "text": "@RobertoRedSox @BrambillaLuca @gplexousted Il \u201cdito di vino\u201d."
#     }
# }
# {
#     "data": {
#         "id": "1508968337778552836",
#         "text": "LET\u2019S MANGE A RESORT TOGETHER!https://t.co/qKejFqKITn"
#     }
# }
# {
#     "data": {
#         "id": "1508968337782591491",
#         "text": "Por mi salud y los dem\u00e1s usuarios seguir\u00e9 usando pantalla facial en @OficialMiBus \n\nEste virus no acaba y es mejor seguir cuidandonos"
#     }
# }
# {
#     "data": {
#         "id": "1508968337786937349",
#         "text": "RT @shyoskyy: \u0e44\u0e21\u0e48\u0e02\u0e2d\u0e15\u0e31\u0e14\u0e2a\u0e34\u0e19\u0e27\u0e48\u0e32 Will Smith \u0e1c\u0e34\u0e14\u0e2b\u0e23\u0e37\u0e2d\u0e16\u0e39\u0e01 \u0e41\u0e15\u0e48\u0e40\u0e23\u0e32\u0e21\u0e2d\u0e07\u0e27\u0e48\u0e32\u0e40\u0e02\u0e32\u0e40\u0e1b\u0e47\u0e19\u0e2a\u0e32\u0e21\u0e35\u0e17\u0e35\u0e48\u0e2d\u0e22\u0e39\u0e48\u0e02\u0e49\u0e32\u0e07\u0e46\u0e20\u0e23\u0e23\u0e22\u0e32\u0e15\u0e2d\u0e19\u0e01\u0e33\u0e25\u0e31\u0e07\u0e1b\u0e48\u0e27\u0e22 \u0e01\u0e32\u0e23\u0e17\u0e35\u0e48\u0e1c\u0e0d.\u0e04\u0e19\u0e19\u0e36\u0e07\u0e15\u0e49\u0e2d\u0e07\u0e40\u0e08\u0e2d\u0e01\u0e31\u0e1a\u0e2d\u0e32\u0e01\u0e32\u0e23\u0e1b\u0e48\u0e27\u0e22\u0e41\u0e1a\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968337799323649",
#         "text": "RT @michelle_byoung: @aaron_shoaf_321 @POTUS Young man you should delete this tweet before it comes back to haunt you. Nobody should be on\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968337790877698",
#         "text": "RT @ejeancarroll: Every week @MaryLTrump gives us the latest FASCIST SCORES.\n\nShe gives the score for the top 70 posts on Facebook\n\nThe New\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968337782493188",
#         "text": "@MuseuBFR Eu vi...kkkkk as coisas realmente est\u00e3o mudando."
#     }
# }
# {
#     "data": {
#         "id": "1508968337799368707",
#         "text": "@KSNogueiraa disse q foi descendo a ladeira da frente do ifba \nman, va andando nn\nqnd for me fale q a gnt vai junto nos dia q a gnt sair 20h20"
#     }
# }
# {
#     "data": {
#         "id": "1508968337778393090",
#         "text": "entrar no ttk e ver o \u201c99+\u201d \u00e9 a melhor parte do meu dia"
#     }
# }
# {
#     "data": {
#         "id": "1508968337786744832",
#         "text": "RT @nobodylaura18: i still haven\u2019t recovered https://t.co/AJAxIr3BrD"
#     }
# }
# {
#     "data": {
#         "id": "1508968337778298886",
#         "text": "@Minami707chan @lilcandy100 Sure they can! You just either need the right attitude, the right tools, the right sneakiness, or the right plan"
#     }
# }
# {
#     "data": {
#         "id": "1508968337795170306",
#         "text": "RT @LucianaAllu: Claro que eu apoio. Cara t\u00e1 sendo perseguido e criminalizado com inqu\u00e9rito ilegal e inconstitucional\n#EuapoioDanielSilveira"
#     }
# }
# {
#     "data": {
#         "id": "1508968341997862912",
#         "text": "Vontade de voltar com o Gabriel no nick."
#     }
# }
# {
#     "data": {
#         "id": "1508968341989376008",
#         "text": "@NaraGalvao_ Qual foi parceira\ud83e\udd28\ud83e\udd28, pensa coisa errada n\u00e3o, s\u00f3 fiz manuten\u00e7\u00e3o"
#     }
# }
# {
#     "data": {
#         "id": "1508968341981077510",
#         "text": "RT @WrestleFeatures: Seth Rollins &amp; Kevin Owens have built their WrestleMania stories without having anyone else to work off.\n\nThey are two\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968341968498688",
#         "text": "@guizincriaa faltou tu a\u00ed"
#     }
# }
# {
#     "data": {
#         "id": "1508968342001909765",
#         "text": "RT @yuzin333: \u7518\u96e8 #\u539f\u795e https://t.co/Xt7wVcup8K"
#     }
# }
# {
#     "data": {
#         "id": "1508968341985120260",
#         "text": "RT @yurayura_yuraa: \u304a\u306f\u3086\u3089\uff01\n\u3000#\u3086\u3089\u3086\u3089\u9031\u30d7\u30ec\u8868\u7d19\u3000\u0295\u2022\u1d25\u2022\u0294 https://t.co/Leh963pH8I"
#     }
# }
# {
#     "data": {
#         "id": "1508968341993828353",
#         "text": "\u604b\u306f\u3001\u9060\u3044\u65e5\u306e\u82b1\u706b\u3067\u306f\u306a\u3044\u3002(\u30b5\u30f3\u30c8\u30ea\u30fc\u3000by\u5c0f\u91ce\u7530\u9686\u96c4\u3000in1994)"
#     }
# }
# {
#     "data": {
#         "id": "1508968341964300290",
#         "text": "RT @Epona71505494: https://t.co/s8bZkwe3vD"
#     }
# }
# {
#     "data": {
#         "id": "1508968341985447940",
#         "text": "RT @V3RV3R1VW4Y: \uc8fd\uc9c0\ub3c4 \uc54a\uace0 \ub610 \uc654\uc2b5\ub2c8\ub2e4...\n\uc2a4\uc0f7\uacfc \uac19\uc740 \uc0ac\uc720\ub85c \uc778\ud574 \n\uc54c\ud2f0\ud574\uc8fc\uc2e0 \ubd84\ub4e4\uc911 \ucd1d \ub450 \ubd84\uc744 \ubf51\uc544 5\uc6d4\uc911\uc73c\ub85c \ud658\uc0c1\uc57d\uc744 \ub2e4\uc2dc \ud55c\ubc88 \uc120\ubb3c\ud574\ub4dc\ub9bd\ub2c8\ub2e4(\ud55c\uae00\uc12d \uc0c1\uad00\uc5c6\uc74c) https://t.co/HkPXft6pyx"
#     }
# }
# {
#     "data": {
#         "id": "1508968341985271809",
#         "text": "RT @ounojo: vcs tbm ficam chateado com a mentalidade das pessoa? tipo... \"crIh  tu realmente pensa assim??\""
#     }
# }
# {
#     "data": {
#         "id": "1508968342001885184",
#         "text": "\u5922\u306f\u56de\u907f\u3057\u305f\uff01\uff01\uff01\u306a\uff1f\uff1f\uff1f\uff1f"
#     }
# }
# {
#     "data": {
#         "id": "1508968341980925952",
#         "text": "@AgusPeralta2122 Si alto fr\u00edo hace loko\ud83d\ude20\ud83d\ude20"
#     }
# }
# {
#     "data": {
#         "id": "1508968341976854533",
#         "text": "\u8d77\u304d\u305f\u3089\u7d42\u308f\u3063\u3066\u305fw \u5f15\u304d\u7d9a\u304d\u9632\u885b\u30e9\u30a4\u30f3\u7dad\u6301\uff1f\u3059\u308b\u305f\u3081\u306b\u9811\u5f35\u308bw"
#     }
# }
# {
#     "data": {
#         "id": "1508968341972692996",
#         "text": "@parkggelic aunque pudiera me lo quitan y se ponen a ver una peli de terror con la t\u00edpica final girl\n\npero puedo menearme el pelo frente a ellos con una mascaraebatman"
#     }
# }
# {
#     "data": {
#         "id": "1508968341964210176",
#         "text": "https://t.co/LJgTixoKC2"
#     }
# }
# {
#     "data": {
#         "id": "1508968341968359424",
#         "text": "@prakashraaj Prakash raj tum kaha miloge nafart ho rhi tumse deshdrohi sala\nTujhe is hindustan me rahne ka koi haq nhi hai"
#     }
# }
# {
#     "data": {
#         "id": "1508968342002057223",
#         "text": "RT @sinopsesreal: https://t.co/lzidD82aly"
#     }
# }
# {
#     "data": {
#         "id": "1508968341985120258",
#         "text": "1508968337291857925"
#     }
# }
# {
#     "data": {
#         "id": "1508968341989437444",
#         "text": "RT @SinSalmoneras: @nico_grau @julio_salas @JorgeFlies @AndreaGoreAysen @max_bello_m @FlaviaLiberona @eziocosta @LeticiaCaro6 \nEl @Gobierno\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968341972692993",
#         "text": "RT @fiImcunt: https://t.co/d8HLEgkSs7"
#     }
# }
# {
#     "data": {
#         "id": "1508968341968465923",
#         "text": "RT @UA_Leka: \u0421\u043b\u0443\u0448\u043d\u0430 \u0434\u0443\u043c\u043a\u0430."
#     }
# }
# {
#     "data": {
#         "id": "1508968341997768710",
#         "text": "@Zero_TG Exacto, sin raci\u00f3n recomendada de prote\u00edna cuenta como botana. Si llevar\u00e1 carne,pollo,etc te lo doy por bueno que es guisado"
#     }
# }
# {
#     "data": {
#         "id": "1508968342002012163",
#         "text": "UwU I like the 6B pencil in procreate https://t.co/a8GPsyLdPn"
#     }
# }
# {
#     "data": {
#         "id": "1508968341985443840",
#         "text": "@gemhostofficial @Vegeta_eth @SyeraPromotes @ShanayaPromotes @DacxiCoin https://t.co/ISDutS3RvJ"
#     }
# }
# {
#     "data": {
#         "id": "1508968341964308483",
#         "text": "RT @rejectedhannah: Will apologized, Chris isn\u2019t pressing charges, everyone\u2019s time to get ur thoughts in ended around 2 pm yesterday, let\u2019s\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968341993533441",
#         "text": "Ajajaja soy forra cuando quiero"
#     }
# }
# {
#     "data": {
#         "id": "1508968341976674306",
#         "text": "\u9df9\u5d0e\u5948\u6d25\u300c\u304b\u30fb\u3066\u30fb\u308b\u30fb\u3088\uff01\uff01\u300d"
#     }
# }
# {
#     "data": {
#         "id": "1508968341993578497",
#         "text": "Untouchable\ud83e\udee0 https://t.co/JjNyeXg1ga"
#     }
# }
# {
#     "data": {
#         "id": "1508968341997867010",
#         "text": "@ninimeugostosao ELE \u00c9 MEU PROTEGIDINHO AMG, VC GOSTA DELE??"
#     }
# }
# {
#     "data": {
#         "id": "1508968341972660225",
#         "text": "RT @HeitorBelini: Tem dias que \u00e9 s\u00f3 pela Gra\u00e7a. (Uns 365 por ano)"
#     }
# }
# {
#     "data": {
#         "id": "1508968341972525061",
#         "text": "RT @Ottila6: https://t.co/T8TgdifrKt"
#     }
# }
# {
#     "data": {
#         "id": "1508968341985189894",
#         "text": "RT @juicyyboo__: Do you miss this ass ? \ud83e\udd70 https://t.co/GlB5b0OZii"
#     }
# }
# {
#     "data": {
#         "id": "1508968341997764619",
#         "text": "RT @andreshalders: Tr\u00eas anos sem nenhum caso de governo na corrup\u00e7\u00e3o"
#     }
# }
# {
#     "data": {
#         "id": "1508968341968502792",
#         "text": "RT @kkiwicake: It takes less than a day to reach Tigray Mekelle from Semera. However, no aid truck has reached to #Tigray so far. We need m\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968341964214280",
#         "text": "@teamhollcker @Enaldinho1 @Enaldinho1 CORRE AQUI"
#     }
# }
# {
#     "data": {
#         "id": "1508968341964484612",
#         "text": "\u8acb\u8b93\u4ed6\u53c3\u52a0\u5c0f\u68ee\u6797\u9019\u985e\u5e36\u5c0f\u5b69\u7684\u7bc0\u76ee\u5427 https://t.co/uzVAQk18GV"
#     }
# }
# {
#     "data": {
#         "id": "1508968341997826054",
#         "text": "Fazendo absolutamente qualquer coisa:\nMinha mente: Y NO TE VOY A ENVOLVER"
#     }
# }
# {
#     "data": {
#         "id": "1508968341989437443",
#         "text": "RT @thymesrealgf: i need them pictures \ud83e\udd27\n\n#tontawan_t #bbrightvc https://t.co/aNF3XS4nF3"
#     }
# }
# {
#     "data": {
#         "id": "1508968341985132545",
#         "text": "\u0939\u094b\u092e\u0917\u093e\u0930\u094d\u0921\u094d\u0938 \u0935\u093f\u092d\u093e\u0917 \u092e\u0947\u0902 37 \u092a\u0926 \u0930\u093e\u091c\u094d\u092f \u0915\u0930\u094d\u092e\u091a\u093e\u0930\u0940 \u0926\u0930\u094d\u091c\u093e (\u0935\u0948\u0924\u0928\u093f\u0915) \u0928\u093f\u092f\u092e\u093f\u0924 \u0921\u094d\u092f\u0942\u091f\u0940 \u092a\u093e \u0938\u0915\u0924\u0947 \u0939\u0948\u0902\u0964\n\u0939\u094b\u092e\u0917\u093e\u0930\u094d\u0921\u0938 \u0935\u093f\u092d\u093e\u0917 \u091c\u093f\u0938\u0915\u0947 \u0928\u093e\u092e \u092a\u0930 \u092a\u0942\u0930\u093e \u0935\u093f\u092d\u093e\u0917 \u091a\u0932 \u0930\u0939\u093e \u0939\u0948 \u0924\u094b \u0938\u093f\u0930\u094d\u092b \u090f\u0915 \u092a\u0926 \u0915\u094b (\u0905\u0935\u0948\u0924\u0928\u093f\u0915 \u0939\u094b\u092e\u0917\u093e\u0930\u094d\u0921\u0938 \u091c\u0935\u093e\u0928) \u0915\u094b \u0930\u093e\u091c\u094d\u092f \u0915\u0930\u094d\u092e\u091a\u093e\u0930\u0940 \u0926\u0930\u094d\u091c\u093e \u0935 \u0928\u093f\u092f\u092e\u093f\u0924 \u0921\u094d\u092f\u0942\u091f\u0940 \u0915\u094d\u092f\u094b\u0902 \u0928\u0939\u0940\u0902 \u0926\u093f\u092f\u093e \u091c\u093e \u0930\u0939\u093e \u0939\u0948? https://t.co/Lx5NWSqqnx\nNp"
#     }
# }
# {
#     "data": {
#         "id": "1508968346183778309",
#         "text": "@physicallvs SI HERMANA"
#     }
# }
# {
#     "data": {
#         "id": "1508968346166906887",
#         "text": "@Kevinibarguen10 @Albirroja @SeleccionPeru Siga ri\u00e9ndose con esos 2 de Per\u00fa jajajajaja\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23"
#     }
# }
# {
#     "data": {
#         "id": "1508968346183688199",
#         "text": "RT @harrylitman: 2 more points about the 457-minute gap in the call logs:  1) additional strong evidence of intent to obstruct, in the very\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968346179579915",
#         "text": "Laying *"
#     }
# }
# {
#     "data": {
#         "id": "1508968346158612487",
#         "text": "@nnandinhax E vc sequestrou"
#     }
# }
# {
#     "data": {
#         "id": "1508968346179731456",
#         "text": "RT @iwatebuin: @hosono_54 \u4eca\u3001\u5de6\u6d3e\u7cfb\u65b0\u805e\u4e2d\u5fc3\u306b\u30ab\u30ec\u30fc\u30e9\u30a4\u30b9\u554f\u984c\u53d6\u308a\u4e0a\u3052\u3066\u307e\u3059\u304c\u3001\u5236\u670d\u7d44\u3084\u4e8b\u52d9\u65b9\u306a\u3069\u306e\u533a\u5206\u7121\u3057\u306b\u5168\u54e1\u56fd\u8cbb\u3067\u98df\u3079\u3055\u305b\u3066\u304f\u3060\u3055\u3044\u3088\u3002\u7d44\u7e54\u5185\u306b\u8981\u3089\u306a\u3044\u58c1\u3092\u9020\u308a\u9023\u5e2f\u611f\u3092\u524a\u3050\u3088\u3046\u306a\u898f\u5b9a\u306f\u898b\u76f4\u3059\u3079\u304d\u3067\u3059\u3002\u672c\u5f53\u306b\u304f\u3060\u3089\u306a\u3044\u3002\u707d\u5bb3\u6d3b\u52d5\u3084\u56fd\u9632\u3092\u62c5\u3046\u7d44\u7e54\u3067\u3059\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968346187968515",
#         "text": "@MamaeEngordei Pera como assim n\u00e3o \u00e9 \ud83d\ude26"
#     }
# }
# {
#     "data": {
#         "id": "1508968346183618561",
#         "text": "Genuinely, CARNIVAL OF SOULS is one of the most nightmarish movies ever made. Be there! https://t.co/AIAP6VTK5I"
#     }
# }
# {
#     "data": {
#         "id": "1508968346192125957",
#         "text": "@MarchaDaFamili1 Vamos mostrar nosso apoio a esse homem de coragem.\n#EuapoioDanielSilveira"
#     }
# }
# {
#     "data": {
#         "id": "1508968346192121865",
#         "text": "@Furaozinhos @badbitchseb nunca vi hp, deve ser fofo"
#     }
# }
# {
#     "data": {
#         "id": "1508968346162765830",
#         "text": "RT @salhabosalh92: \u0633\u0627\u0646\u062f\u0628\u0631\u063a \u0632\u0644\u062a \u0632\u0631\u0627\u062f\u0634\u062a \u0633\u0627\u062e\u0631\u0629\n\u2728\n\u0646\u0648\u0646   MK100\n\n\u0627\u0646\u0627\u0633 \u0627\u0648\u0646\u0627\u0633   A225"
#     }
# }
# {
#     "data": {
#         "id": "1508968341968683010",
#         "text": "RT @cinematoday: \u300c#\u7279\u635c9\u300d\u65b0\u52a0\u5165\u306eSnow Man #\u5411\u4e95\u5eb7\u4e8c \u3001 #\u4e95\u30ce\u539f\u5feb\u5f66 \u306e\u512a\u3057\u3055\uff06\u30a2\u30c9\u30d0\u30a4\u30b9\u306b\u611f\u52d5\uff01\n#SnowMan #season5 https://t.co/hyBFqplZd4"
#     }
# }
# {
#     "data": {
#         "id": "1508968346158616584",
#         "text": "RT @reescrevi_frase: a pessoa q eu mais precisava me ensinou que eu n\u00e3o preciso de ningu\u00e9m."
#     }
# }
# {
#     "data": {
#         "id": "1508968346166964226",
#         "text": "RT @Mreverything_22: After this season\u2026. Coke"
#     }
# }
# {
#     "data": {
#         "id": "1508968346179440645",
#         "text": "RT @nicetxx45: \u0e2b\u0e22\u0e34\u0e48\u0e19\u0e27\u0e2d\u0e23\u0e4c\u0e14\u0e39\u0e41\u0e25\u0e01\u0e31\u0e19\u0e42\u0e14\u0e22\u0e2d\u0e31\u0e15\u0e42\u0e19\u0e21\u0e31\u0e15\u0e34\u0e2d\u0e30 \u0e41\u0e1a\u0e1a\u0e40\u0e2b\u0e47\u0e19\u0e2d\u0e30\u0e44\u0e23\u0e41\u0e1b\u0e01\u0e46\u0e43\u0e19\u0e15\u0e31\u0e27\u0e2d\u0e35\u0e01\u0e04\u0e19\u0e21\u0e37\u0e2d\u0e01\u0e47\u0e2d\u0e22\u0e39\u0e48\u0e44\u0e21\u0e48\u0e2a\u0e38\u0e01\u0e41\u0e25\u0e49\u0e27 \u0e17\u0e31\u0e49\u0e07\u0e08\u0e31\u0e1a\u0e1c\u0e21\u0e40\u0e0b\u0e47\u0e17\u0e1c\u0e21 \u0e40\u0e0a\u0e47\u0e14\u0e2b\u0e19\u0e49\u0e32\u0e43\u0e2b\u0e49 \u0e08\u0e31\u0e1a\u0e40\u0e2a\u0e37\u0e49\u0e2d\u0e43\u0e2b\u0e49 \u0e40\u0e2b\u0e47\u0e19\u0e27\u0e48\u0e32\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968346192351232",
#         "text": "@Mo_Tomz @UTDDownSouth @TyMarshall_MEN \"The treatment of Alexis Sanchez is basically just parody now. Really, really odd. He was in the team of the tournament in the PL less than 12 months ago. He\u2019s not an 350k a week attacker, but he\u2019s clearly not useless either is he? Let\u2019s not forget City wanted him in 2018\""
#     }
# }
# {
#     "data": {
#         "id": "1508968346162966530",
#         "text": "RT @nishiuyu: \u96c4\u5927\u306f\u30cb\u30e4\u30cb\u30e4\u3057\u3066\u308b\u3057\u3001\u67fe\u54c9\u306f\u898b\u5b88\u308b\u611f\u3058\u6bcd\u3060\u3057\n\u304a\u4e92\u3044\u8e0a\u3063\u3066\u308b\u6642\u30c1\u30e9\u30c1\u30e9\u307f\u3066\u308b\u306e\u53ef\u611b\u3044\n#INI #INI_I #\u6728\u6751\u67fe\u54c9 #\u4f50\u91ce\u96c4\u5927 #\u30c8\u30c8\u5144\u5f1f #WeAre https://t.co/YX2bkaH03t"
#     }
# }
# {
#     "data": {
#         "id": "1508968346192343040",
#         "text": "RT @A100888: $30 \u2022 3 winners - $10 each - Rt\n\n15 mins /7.05am"
#     }
# }
# {
#     "data": {
#         "id": "1508968346196541440",
#         "text": "RT @Artrockerz: I'm sorry if someone think I will write anything serious. It is not...\n#\u4e94\u4e03 https://t.co/Ryils9iCaK"
#     }
# }
# {
#     "data": {
#         "id": "1508968346196525057",
#         "text": "RT @kakiharuka_1st: \u4e43\u6728\u574246 #\u8cc0\u559c\u9065\u99991st\u5199\u771f\u96c6 \u304c6\u67087\u65e5\u306b\u767a\u58f2\u6c7a\u5b9a\uff01\n\n\u8cc0\u559c\u3055\u3093\u304b\u3089\u7686\u69d8\u3078\u30e1\u30c3\u30bb\u30fc\u30b8\u3067\u3059\u2661\n\n\u2728\u30a2\u30de\u30be\u30f3\nhttps://t.co/7DRH7pWwn2\n\n\u2728\u697d\u5929\uff08\u9650\u5b9a\u7248\uff09\nhttps://t.co/XauZ3GiImH\n\n\u2728\u30bb\u30d6\u30f3\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968346183938048",
#         "text": "RT @KinKi_support: [ftr][\u525b][TV]\u672c\u65e5\u653e\u9001\uff62Premium Music 2022\uff63(\u65e5\u30c6\u30ec\u7cfb\u30fb19:00\uff5e22:54)\n\uff62THE\u591c\u3082\u30d2\u30c3\u30d1\u30ec\uff63\u4e00\u591c\u9650\u308a\u306e\u5fa9\u6d3b\u4f01\u753b\uff01\u30c7\u30d3\u30e5\u30fc\u524d\u306eKinKi Kids\u304c\u6b4c\u3046\u4e2d\u5cf6\u307f\u3086\u304d\u306a\u3069\u306e\u304a\u5b9d\u6620\u50cf\uff01\n\uff62\u91d1\u7530\u4e00\u5c11\u5e74\u306e\u4e8b\u4ef6\u7c3f\uff63\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968346171195397",
#         "text": "@i4ysng https://t.co/zmZD8ByNkZ"
#     }
# }
# {
#     "data": {
#         "id": "1508968346167181313",
#         "text": "\u304b\u308f\u3044\u3044\u2764\ufe0f\n\u592b\u5a66\u3067\u304a\u63c3\u3044\u306b\u3057\u305f\u3044\ud83d\udc55\n#\u30e6\u30cb\u30af\u30ed\u306e\u904a\u3079\u308bUT\u30eb\u30fc\u30ec\u30c3\u30c82022 https://t.co/kku76jVYq4"
#     }
# }
# {
#     "data": {
#         "id": "1508968346162991104",
#         "text": "RT @uratasama: \u304a\u3084\u3059\u3059\u3059\u307f\uff01\uff01\n\n\u304a\u306f\u30c4\u30a410\u6642\u306e\u3064\u3082\u308a\u3060\u3051\u3069\u3044\u3064\u3082\u901a\u308a\u8d77\u304d\u3061\u3083\u3063\u305f\u30897\u6642\u3068\u304b\u3067\uff01\n\n\u304a\u3084\u3059\uff01"
#     }
# }
# {
#     "data": {
#         "id": "1508968346158518272",
#         "text": "RT @housewifegifs: Gia\u2019s face is the face of someone who came ready for WAR #RHONJ https://t.co/eSrRI9INZz"
#     }
# }
# {
#     "data": {
#         "id": "1508968346187808771",
#         "text": "@buya_chan \u304a\u306f\u3088\u3046\u3054\u3056\u3044\u307e\u3059\u30fc\u30fc\uff01\n\u671d\u304b\u3089\u3076\u3084\u3055\u3093\u306e\u53ef\u611b\u3044\u58f0\u304c\u805e\u3051\u3066\n\u4ed5\u4e8b\u9811\u5f35\u308c\u307e\u3059\u30fc\uff01\u3053\u308c\u306f\u76ee\u899a\u307e\u3057\u306b\u3082\u3063\u3066\u3053\u3044\u3067\u306f\uff1f\uff1f"
#     }
# }
# {
#     "data": {
#         "id": "1508968346170978307",
#         "text": "RT @yourgrend: \u0e2a\u0e16\u0e32\u0e19\u0e30\u0e02\u0e2d\u0e07\u0e2b\u0e31\u0e27\u0e43\u0e08\u0e15\u0e2d\u0e19\u0e19\u0e35\u0e49\u0e44\u0e21\u0e48\u0e04\u0e48\u0e2d\u0e22\u0e08\u0e30\u0e14\u0e35\u0e19\u0e31\u0e01 : https://t.co/EuMGaHj4Er"
#     }
# }
# {
#     "data": {
#         "id": "1508968346162991108",
#         "text": "Gracias por el cari\u00f1o que nos dannnnn \u2764\ufe0f\u2764\ufe0f\u2764\ufe0f"
#     }
# }
# {
#     "data": {
#         "id": "1508968346162765831",
#         "text": "t\u00e1, agr preciso de vc jimin :("
#     }
# }
# {
#     "data": {
#         "id": "1508968346158575625",
#         "text": "RT @Rome_Beast: i\u2019m cryin brah https://t.co/27nGSyYLZX"
#     }
# }
# {
#     "data": {
#         "id": "1508968346175242240",
#         "text": "@OmoJIFPPNNtXASI \u0e14\u0e35\u0e04\u0e31\u0e1a"
#     }
# }
# {
#     "data": {
#         "id": "1508968346187968514",
#         "text": "Bacon IB Central Ball Kyat Toys Configuration violet invoice Kids Intelligent Tasty https://t.co/JC0zjuQTy4"
#     }
# }
# {
#     "data": {
#         "id": "1508968346158452737",
#         "text": "morning @fiasdaily"
#     }
# }
# {
#     "data": {
#         "id": "1508968346187927562",
#         "text": "D\u00eda 300 de marzo..."
#     }
# }
# {
#     "data": {
#         "id": "1508968346179436546",
#         "text": "RT @Kingfrost3131: @OldMemeArchive https://t.co/CxaBuiIj5Z"
#     }
# }
# {
#     "data": {
#         "id": "1508968346175291395",
#         "text": "\ud83d\udea8GOAL\ud83d\udea8\n\nClarke Central equalized in minute 52. \n#introsport22 @DOrlandoLED"
#     }
# }
# {
#     "data": {
#         "id": "1508968346162671625",
#         "text": "RT @stnalx: Join our Scener watch party here: https://t.co/6ap5HUGfVZ\n\nJoin stationhead streaming party as well: https://t.co/UYrqqhLtqj\n\n#\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968346183630848",
#         "text": "RT @msiswakeadilan: Kenyataan Media - Untuk Siaran Segera: Prof. Dr. Ts. Roshana Takim Harus Dikenakan Tindakan Tatatertib\n\n#MahasiswaKEADI\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968346175348743",
#         "text": "RT @chiiyochiiyo: cute gyaru for tonight \ud83d\udc95 https://t.co/iDeQikCTPv"
#     }
# }
# {
#     "data": {
#         "id": "1508968346166784003",
#         "text": "RT @Sanjana_Khanna_: desi swingers\n\n2/2 https://t.co/7q4NR96diB"
#     }
# }
# {
#     "data": {
#         "id": "1508968346179575814",
#         "text": "@DalmauSenador @ppdpr Usted qu\u00e9 mensaje vio? Obvio que no fue el que se dio esta noche en la C\u00e1mara de Representantes. O ser\u00e1 que alucina pq no puede aceptar la realidad? Que fue un mensaje de logros irrefutables. #LosHechosSonLosHechos Despierte de una vez!"
#     }
# }
# {
#     "data": {
#         "id": "1508968346179432448",
#         "text": "RT @jnkrated: https://t.co/5XYaThdc46"
#     }
# }
# {
#     "data": {
#         "id": "1508968346183782404",
#         "text": "\u062d\u064a\u0627\u0647 \u0627\u0644\u0645\u064a\u0645 \u0644\u0648\u0631\u062f \u062f\u064a \u0635\u0639\u0628\u0647 \u0627\u0648\u064a"
#     }
# }
# {
#     "data": {
#         "id": "1508968350352879616",
#         "text": "RT @NurgunYarar: D\u00f6neceksinte \ud83d\uddef\ufe0fM\u0131s\u0131nta benim te imkan\u0131m\u00fcmk\u00fcn ecekler \ud83d\udd3bUnuttur tum #antalyatrave\ufb05i https://t.co/L81N6UqSf5"
#     }
# }
# {
#     "data": {
#         "id": "1508968350382231552",
#         "text": "@coquito_sama Take care and I hope you\u2019re able to rest and recharge well \ud83d\udc23\ud83d\udc9e"
#     }
# }
# {
#     "data": {
#         "id": "1508968350352916480",
#         "text": "RT @NurgunYarar: D\u00f6neceksinte \ud83d\uddef\ufe0fM\u0131s\u0131nta benim te imkan\u0131m\u00fcmk\u00fcn ecekler \ud83d\udd3bUnuttur tum #antalyatrave\ufb05i https://t.co/L81N6UqSf5"
#     }
# }
# {
#     "data": {
#         "id": "1508968350361210890",
#         "text": "@TheRock Bro look like a paper man was inflated"
#     }
# }
# {
#     "data": {
#         "id": "1508968350377984003",
#         "text": "RT @jaloverde: Que buena frase es Asokeapa soguegui"
#     }
# }
# {
#     "data": {
#         "id": "1508968350369603589",
#         "text": "@falahhussein_72 \u062f\u062e\u064a\u0644 \u0627\u0644\u0644\u0647 \u0627\u0630\u0627 \u0627\u0644\u0643\u0641\u0643"
#     }
# }
# {
#     "data": {
#         "id": "1508968350382276611",
#         "text": "RT @BanditTravis: Can you spot my problem? Zoom in on everything! What is my violation I prevented??? https://t.co/ZkBlUcKel5"
#     }
# }
# {
#     "data": {
#         "id": "1508968350382133251",
#         "text": "\u30de\u30de\u6d3b\u3092\u611b\u3057\u3066\u308b20\u4ee3\u3067\u3059\ud83d\udc96\u304a\u663c\u306b\u30c7\u30fc\u30c8\u3084\u591c\u306e\u30d9\u30c3\u30c9\u306e\u4e0a\u3067\u306e\u304a\u4f9b\u3092\u3057\u3066\u304f\u308c\u308b\u7537\u6027\u3092\u52df\u96c6\u3057\u3066\u304a\u308a\u307e\u3059\ud83d\ude33\n\u30d5\u30a9\u30ed\u30fc\u3057\u3066\u304f\u308c\u305f\u3089\u3068\u3066\u3082\u559c\u3073\u307e\u3059\ud83d\ude2d\n\u7d39\u4ecb\u306f\u5168\u56fd\u53ef\u80fd\u53ef\u80fd\u306a\u306e\u3067\u6c17\u306b\u306a\u308b\u65b9\u306fURL\u304b\u3089\u30af\u30ea\u30c3\u30af\u5b9c\u3057\u304f\u3067\u3059\u266a\ud83d\udc96\n\nhttps://t.co/eGf58mFv2g https://t.co/RO2AdBSIz8"
#     }
# }
# {
#     "data": {
#         "id": "1508968350378041349",
#         "text": "IB methodologies Sharable Port Phased Dynamic Ethiopian Crossing compress Cheese collaborative red https://t.co/BSgO1WfcSK"
#     }
# }
# {
#     "data": {
#         "id": "1508968350365499395",
#         "text": "RT @Gleybert: - Va a pagar con d\u00f3lares?\n+ No\n+ Bol\u00edvares?\n- No\n+ Criptomonedas?\n- No\n+ Bueno y entonces?\n- Esto es un atraco\n+ Ahhh del Sen\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968350369697799",
#         "text": "RT @endycontreras: #DiplomaciaBolivarianaDePaz #VolvemosAlAula\n\ud83c\uddea\ud83c\uddec\ud83e\udd1d\ud83c\udffc\ud83c\uddfb\ud83c\uddea"
#     }
# }
# {
#     "data": {
#         "id": "1508968341989433346",
#         "text": "@gb9172128 \u0647\u0644\u0627"
#     }
# }
# {
#     "data": {
#         "id": "1508968346188156928",
#         "text": "\u304a\u308f\u3063\u3068\u3001\u30c9\u30e9\u30de\u59cb\u307e\u3063\u3061\u3083\u3046\u3088\u3002"
#     }
# }
# {
#     "data": {
#         "id": "1508968346192158724",
# ...
#     }
# }
# {
#     "data": {
#         "id": "1508968354584821765",
#         "text": "@MIKITO_777 \ud83d\udd95"
#     }
# }
# {
#     "data": {
#         "id": "1508968354555449347",
#         "text": "RT @RiverLPM: \ud83d\udd78\ufe0f\ud83d\udd77\ufe0f En su primer partido como titular, Juli\u00e1n \u00c1lvarez anot\u00f3 el 1 a 0 para la Argentina en su visitia a Ecuador. Debut en la\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968354559709184",
#         "text": "@Clix https://t.co/vmhhhekFpU"
#     }
# }
# {
#     "data": {
#         "id": "1508968354559713285",
#         "text": "@AlvaroRM___ Sueltame el brazo"
#     }
# }
# {
#     "data": {
#         "id": "1508968354572341259",
#         "text": "RT @BigSoSoXxX: \u0641\u064a\u0644\u0645 30 \u062f\u0642\u064a\u0642\u0647 \u0644\u0634\u0631\u0645\u0648\u0637\u0647 \u0645\u0635\u0631\u064a\u0647 \u0628\u062c\u0633\u0645 \u0645\u0631\u0628\u0631\u0628 \u0645\u0639 \u062c\u0648\u0632\u0647\u0627 \u0627\u0644\u062d\u0648\u0644 \u0647\u0649 \u0627\u0644\u0644\u0649 \u0628\u062a\u0646\u064a\u0643\u0648 \u0648\u064a\u0641\u0631\u062c \u0627\u0644\u0646\u0627\u0633 \u0639\u0644\u0649 \u062c\u0633\u0645\u0647\u0627 \u0627\u0644\u0645\u0644\u0628\u0646 \u0627\u0644\u0645\u0645\u062d\u0648\u0646 \u0648\u0627\u062d\u0644\u0649 \u0627\u0647\u0627\u062a \u0648\u0643\u0644\u0627\u0645\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968354580738050",
#         "text": "RT @buitengebieden_: Leopard cub sneaks on its mom.. \ud83d\ude05 https://t.co/pegGAhKK3U"
#     }
# }
# {
#     "data": {
#         "id": "1508968354563825672",
#         "text": "RT @Wizardara: \u2694 Mr Wizards #NFT Arts Battle Round 10 \u2694 \n---------------\nDanger Valley\n@danger_valley\n\nvs.\n\nDazedDucks Metagalactic Club\n@D\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968354564153344",
#         "text": "\u3044\u3064\u3082\u5fdc\u63f4\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\ud83d\ude2d https://t.co/FPgem3GE7M"
#     }
# }
# {
#     "data": {
#         "id": "1508968354559803392",
#         "text": "@kaeine09 \n\u3054\u5fdc\u52df\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\uff01\n4/6\u307e\u3067\u4f7f\u3048\u308b\u300c\u30a6\u30c1\u30ab\u30d5\u30a7\u30b9\u30a4\u30fc\u30c4\u5404\u7a2e20\u5186\u5f15\u5238\u300d\u3092\u5dee\u3057\u4e0a\u3052\u307e\u3059\u3002\u307b\u3063\u3068\u3072\u3068\u606f\u306f\u30a6\u30c1\u30ab\u30d5\u30a7\u30b9\u30a4\u30fc\u30c4\u3067\u266a\u6b21\u56de\u3082\u30c1\u30e3\u30ec\u30f3\u30b8\u3057\u3066\u4e0b\u3055\u3044(^^)\n\u30af\u30fc\u30dd\u30f3\u306e\u4f7f\u3044\u65b9:https://t.co/AgLeXBVHKl #\u30ed\u30fc\u30bd\u30f3 https://t.co/Tp5f5HHbmj"
#     }
# }
# {
#     "data": {
#         "id": "1508968354563956739",
#         "text": "@CPolarBearC @WillGittens @alqsyy @NotRazorX @khoshy"
#     }
# }
# {
#     "data": {
#         "id": "1508968354580631552",
#         "text": "RT @ike_eveland: @createdtotweet Ahhh this was such a creative little stunt!\nThank you everyone, you're all too kind. ;;"
#     }
# }
# {
#     "data": {
#         "id": "1508968354551377920",
#         "text": "RT @_Gelver_: ALERTA! Militantes y l\u00edderes del Partido Mira @PartidoMIRA en Pereira se niegan  a votar por Federico Guti\u00e9rrez candidato del\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968358762397696",
#         "text": "RT @Weatherdude12: New severe thunderstorm warning for the Oklahoma/Texas border for 1 inch hail and 60mph wind gusts so if you are in the\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968358750081024",
#         "text": "@2panda_kopanda \u767a\u60f3\u529b\u306b\u3073\u3063\u304f\u308a\u3067\u3059\uff01\n\u3074\u3063\u305f\u308a\u7bb1\u306b\u53ce\u307e\u3063\u3066\u3044\u3066\u6c17\u6301\u3061\u3088\u304b\u3063\u305f\u3067\u3059\uff08\u7b11\uff09"
#     }
# }
# {
#     "data": {
#         "id": "1508968358745722882",
#         "text": "@embucetadax @Felipeba1985 Essa parte da hist\u00f3ria vc n\u00e3o me contou hahahah"
#     }
# }
# {
#     "data": {
#         "id": "1508968358770712577",
#         "text": "RT @TRSRVERSE_: [220329] \ud83d\udc2e\ud2b8\ub808\uc800 \uc18c\uc815\ud658\ud83c\udf1f\uc704\ubc84\uc2a4\n\n\"\uc9c4\uc9dc \ud615\uc774 \uc2dc\uc791\ud588\ub2e4\"\n\n\u30c8\u30ec\u30b8\u30e3\u30fc\u30bd\u30fb\u30b8\u30e7\u30f3\u30d5\u30a1\u30f3\nTREASURE SO JUNGHWAN\n@treasuremembers https://t.co/npvFOGTWq4"
#     }
# }
# {
#     "data": {
#         "id": "1508968358745710597",
#         "text": "@kakiageotaku \u3010WINTER/\u51ac\u3011\u5bd2\u3044\u51ac\u306e\u65e5\u306b\uff34\u30b7\u30e3\u30c4\u4e00\u679a\u3067\u5916\u306b\u51fa\u305f\u3089\u98a8\u90aa\u3092\u3072\u3044\u3066\u3057\u307e\u3044\u307e\u3059\u3002\u4eca\u306b\u3042\u3063\u305f\u904e\u3054\u3057\u65b9\u304c\u51fa\u6765\u3066\u3044\u308b\u304b\u78ba\u8a8d\u3057\u307e\u3057\u3087\u3046\u306d\u3002\n\nhttps://t.co/D29MtXsbix\n\n\u30aa\u30e9\u30af\u30eb\u30ab\u30fc\u30c9\u767a\u58f2\u4e2d\uff01\u30b7\u30e7\u30c3\u30d7\u3078\u306e\u30ea\u30f3\u30af\u306f\u30d7\u30ed\u30d5\u304b\u3089"
#     }
# }
# {
#     "data": {
#         "id": "1508968358753943552",
#         "text": "RT @supsross: Flower Girl https://t.co/M7P2PCCSna"
#     }
# }
# {
#     "data": {
#         "id": "1508968354551582722",
#         "text": "\u5922\u3067\u3053\u3068\u308a\u3068\u2026\u2026//\u6b63\u5922\u306b\u306a\u308c\u3070\u3044\u3044\u306e\u306b\u2026\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968354563907584",
#         "text": "@privsgaberu N\u00e3o, n\u00e3o te quero mais"
#     }
# }
# {
#     "data": {
#         "id": "1508968358766596097",
#         "text": "These niggas lmaoooo https://t.co/sK6SkdpgnP"
#     }
# }
# {
#     "data": {
#         "id": "1508968358749741057",
#         "text": "RT @kai_corporation: \uff0f\n#Nulbarich \u3089\u6ce8\u76ee\u30a2\u30fc\u30c6\u30a3\u30b9\u30c8\u304c\u96c6\u3046\n\u300cAUGER\u00ae MUSIC SESSION VOL.1\u300d\n\u3054\u62db\u5f85 #\u30ad\u30e3\u30f3\u30da\u30fc\u30f3\ud83c\udfb6\n\uff3c\n\n5/17(\u6c34)\u306b \u4ee3\u5b98\u5c71UNIT \u306b\u3066\u958b\u50ac\u3059\u308b\n\u5b8c\u5168\u62db\u5f85\u5236\u306e\u97f3\u697d\u30a4\u30d9\u30f3\u30c8\u306b50\u7d44100\u540d\u69d8\u3092\u3054\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968358758260742",
#         "text": "@janet_moore69 https://t.co/KnE0jWjAev"
#     }
# }
# {
#     "data": {
#         "id": "1508968358762405891",
#         "text": "@iris_charo \ud83e\udd70\ud83e\udd70"
#     }
# }
# {
#     "data": {
#         "id": "1508968358758158341",
#         "text": "@Florencilla53 El mismo discurso de los zurdos"
#     }
# }
# {
#     "data": {
#         "id": "1508968358754111493",
#         "text": "@arkinhtt e vc acha q essa thread vai adiantar oq? francamente falando, oq vai mudar?"
#     }
# }
# {
#     "data": {
#         "id": "1508968358749696000",
#         "text": "\uc2a4\ucfe8\ub4dc\uac00 \ud604\uacc4\ud588\ub358\uac74 \uc758\uc678\uc600\ub2e4. \uc5b8\ub2c8 \ub458\uacfc\ub294 \ub2ec\ub9ac \ub9c8\uc74c \ub0b4\ud0a4\ub294\ub300\ub85c \ub2e4\ub2c8\ub294 \ub140\uc11d\uc774\uae34 \ud588\uc9c0\ub9cc, \uc138 \uc790\ub9e4\uac00 \ud558\ub098\ub85c \ub2e4\ub2c8\uc9c0 \uc54a\uc558\ub2e4\ub2c8."
#     }
# }
# {
#     "data": {
#         "id": "1508968358766546946",
#         "text": "RT @juicy_sammy: \u314e\u314e\ud0dc\ud0dc \ub313 \uadc0\uc5fd\uace0 \uc0ac\ub791\uc2a4\ub7fd\ub124\ud83d\ude0d\ud83d\udc95\nI\u2019m listening to #V_ChristmasTree #ChristmasTree by #V all day long @BTS_twt https://t.co/qBAOYPTRIr"
#     }
# }
# {
#     "data": {
#         "id": "1508968358774988807",
#         "text": "RT @geffiboy: A Comm for @Y0SHER  Epic Yosher https://t.co/0KQl6x6V8a"
#     }
# }
# {
#     "data": {
#         "id": "1508968358770843651",
#         "text": "After being wrong for approximately 2.5 days we got dip! \n48.2k gartley triggered but don't hunt my sl now plz familia"
#     }
# }
# {
#     "data": {
#         "id": "1508968358753886208",
#         "text": "Probably nothing https://t.co/00cgyLxeCG"
#     }
# }
# {
#     "data": {
#         "id": "1508968358770794497",
#         "text": "@OnepegMG Holy hell, you\u2019re almost better off selling this and buying a new one off the flea"
#     }
# }
# {
#     "data": {
#         "id": "1508968358754275328",
#         "text": "RT @skyisblueforyou: \u0e2d\u0e31\u0e19\u0e19\u0e35\u0e49\u0e1e\u0e35\u0e40\u0e01\u0e48\u0e07\u0e21\u0e32\u0e01\u0e19\u0e30 \u0e44\u0e21\u0e48\u0e44\u0e14\u0e49\u0e0b\u0e49\u0e2d\u0e21\u0e21\u0e32\u0e01\u0e48\u0e2d\u0e19(\u0e16\u0e36\u0e07\u0e08\u0e30\u0e23\u0e49\u0e2d\u0e07\u0e43\u0e19\u0e07\u0e32\u0e19\u0e2a\u0e27\u0e19\u0e21\u0e32\u0e23\u0e2d\u0e1a\u0e19\u0e36\u0e07\u0e41\u0e25\u0e49\u0e27\u0e41\u0e15\u0e48\u0e2d\u0e31\u0e19\u0e19\u0e35\u0e49\u0e04\u0e35\u0e22\u0e4c\u0e15\u0e33\u0e48\u0e01\u0e27\u0e48\u0e32\u0e21\u0e32\u0e01) \u0e41\u0e16\u0e21\u0e44\u0e21\u0e48\u0e44\u0e14\u0e49\u0e43\u0e2a\u0e48\u0e2d\u0e34\u0e19\u0e40\u0e2d\u0e35\u0e22\u0e23\u0e4c\u0e2d\u0e35\u0e01\u0e40\u0e25\u0e22\u0e15\u0e49\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968358770724866",
#         "text": "RT @MedusaMermelada: cuando estoy enojada o molesta mi cara no lo sabe disimular"
#     }
# }
# {
#     "data": {
#         "id": "1508968358774906881",
#         "text": "@1b5TZ4vNVdCDchV \u56f3\u66f8\u30ab\u30fc\u30c9\u3042\u308b\u304b\u3089\u8cb7\u3048\u306a\u3044\u3053\u3068\u306f\u306a\u3044\u2026\u3051\u3069\u5927\u4e8b\u306b\u3057\u3066\u308b\u306e\u3088www"
#     }
# }
# {
#     "data": {
#         "id": "1508968358774906887",
#         "text": "4\u6642\u9593\u65ad\u6c34\u3059\u308b\u305d\u3046\u3067\u3059\ud83d\ude07\ud83d\ude07"
#     }
# }
# {
#     "data": {
#         "id": "1508968358749913090",
#         "text": "@geglobo \u2764\ufe0f\ud83d\udda4\ud83c\udde7\ud83c\uddf7"
#     }
# }
# {
#     "data": {
#         "id": "1508968358762397701",
#         "text": "Falar com algu\u00e9m que fazia anos que eu n\u00e3o falava \u00e9 sempre bom"
#     }
# }
# {
#     "data": {
#         "id": "1508968358754099206",
#         "text": "@amiarmyamii @SpotifyBrasil Kjkjkjkkkkkkk eu assim kjkjkll tipo tem + uma pessoa aqui ksksksksks"
#     }
# }
# {
#     "data": {
#         "id": "1508968358750076928",
#         "text": "@todays_nyankoo \u304a\u98df\u3079\u3002\u304a\u98df\u3079\u306a\u3055\u3044\u3002\u304a\u98df\u3079\u3002"
#     }
# }
# {
#     "data": {
#         "id": "1508968358779179011",
#         "text": "@BettimGabi caralho deu vontade, quanto custa o peda\u00e7o"
#     }
# }
# {
#     "data": {
#         "id": "1508968358762496004",
#         "text": "@rfZ5tiGHhA9E7gI \u064a \u0633\u0644\u0627\u0645 \u0635\u062d \u0644\u0633\u0627\u0646\u0643"
#     }
# }
# {
#     "data": {
#         "id": "1508968358766645253",
#         "text": "\u4e49a2\u65e0\u52c7\u4e3a\u4e49a2\u65e0\u52c7\u4e3a\n\n\ud83d\udd25\ud83d\udcab\n \u0633\u064a\u0641\u064a   \u2190BE22\u2192\n\n\u0641\u0648\u063a\u0627 \u0643\u0644\u0648\u0633\u064a\u062a  \u0641\u0648\u0642\u0627 \u0643\u0644\u0648\u0633\u062a  \u2190 V1\u2192\nm5A"
#     }
# }
# {
#     "data": {
#         "id": "1508968358770737154",
#         "text": "yo siempre voy a estar para lo que tanto te gusta amiga y te voy a acompa\u00f1ar en lo que sea,me encanta verte tan feliz en eso que tanto quer\u00e9s cumplir y lograr tus metas,ac\u00e1 estoy siempre alent\u00e1ndote @andregramontt_ \ud83e\udd7a\ud83d\udc98 https://t.co/SyZXflnCDz"
#     }
# }
# {
#     "data": {
#         "id": "1508968358774857733",
#         "text": "RT @KonteenSultaan: Video Clip 3 \ud83d\udcfd\n\nTittle: Ada yg berani lawan bini yakuza ? \nFull Duration: 17 menit\n\nUntuk Melihat Koleksi Video Sultan\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968358754013189",
#         "text": "S\u00f3 demonstro carinho perturbando kkkkkk \u00e9 inevit\u00e1vel \ud83e\udd74"
#     }
# }
# {
#     "data": {
#         "id": "1508968358741487617",
#         "text": "RT @apRvfMOIPhexjcy: \u101c\u102c\u1010\u102f\u1014\u103a\u1038\u1000\u1010\u1031\u102c\u1037\u1001\u1036\u1001\u103b\u1004\u103a\u101c\u103d\u1014\u103a\u1038\u101c\u102d\u102f\u1037\u1006\u102d\u102f...\u1021\u1000\u102d\u102f\u1037\u101c\u102e\u1038\u1014\u1032\u1037\u1001\u1036\u1000\u103c\u100a\u103a\u1001\u103b\u1004\u103a\u101c\u102d\u102f\u1037\u1006\u102d\u102f...\u1021\u1000\u102d\u102f\u1037\u1021\u1000\u103c\u102d\u102f\u1000\u103a\u101c\u102d\u102f\u1038\u1015\u102b\u1006\u102d\u102f..\u1001\u102f\u101c\u102d\u102f\u1038\u1010\u1031\u102c\u1037\u1014\u103d\u102c\u1038\u101e\u1000\u103a\u1014\u1031\u101b\u1010\u102c\u1000\u103c\u101c\u102d\u102f\u1037..\u1002\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1508968358754017283",
#         "text": "RT @amandatoyy: Sold my vid! Ass spanking with a whip https://t.co/aVwSQglinE #MVSales https://t.co/MMeAOe1Qym"
#     }
# }
# {
#     "data": {
#         "id": "1508968358741352452",
#         "text": "JAJAJAJSJAKWKQJ https://t.co/g7DIPAaGqL"
#     }
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-af70a55c11f1> in <module>()
#       2 timeout = 0
#       3 while True:
# ----> 4     connect_to_endpoint(url)
#       5     timeout += 1
#       6
#
# <ipython-input-4-830756d6cb01> in connect_to_endpoint(url)
#       2     response = requests.request("GET", url, auth=bearer_oauth, stream=True)
#       3     print(response.status_code)
# ----> 4     for response_line in response.iter_lines():
#       5         if response_line:
#       6             json_response = json.loads(response_line)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     802         pending = None
#     803
# --> 804         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     805
#     806             if pending is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in generate()
#     758             if hasattr(self.raw, 'stream'):
#     759                 try:
# --> 760                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761                         yield chunk
#     762                 except ProtocolError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     596         with self._error_catcher():
#     597             while True:
# --> 598                 self._update_chunk_length()
#     599                 if self.chunk_left == 0:
#     600                     break
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in _update_chunk_length(self)
#     538         if self.chunk_left is not None:
#     539             return
# --> 540         line = self._fp.fp.readline()
#     541         line = line.split(b';', 1)[0]
#     542         try:
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Filtered Stream
#
# We will now see how to get tweets based on certain rules using FilteredStream. Tweets are requested from the URL [SearchStreamURL](https://api.twitter.com/2/tweets/search/stream/rules) <br>
#
# - You can adjust the rules by changing sample_rules under the set_rules function.
# - Here the rules are getting tweets with cat and dog text and images.
#   - The "has" operator will get tweets that are only associated with images.
#   - the "tag" operator is just a string which can be used at a high level to recognize the rule.
# - get_stream prints out the tweets retrieved according to the rules from the filtered stream end point.
# - Once you connect to the FilteredStream endpoint you will keep getting tweets matching the rules through a continuous http streaming connection.
# - Check out [BuildRules](https://developer.twitter.com/en/docs/twitter-api/tweets/filtered-stream/integrate/build-a-rule) for more details on building rules for the filtered stream endpoint.

# %%
def get_rules():
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", auth=bearer_oauth
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    return response.json()

def delete_all_rules(rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        auth=bearer_oauth,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    print(json.dumps(response.json()))

    
def set_rules(delete):
    # You can adjust the rules if needed
    sample_rules = [
        {"value": "dog has:images", "tag": "dog pictures"},
        {"value": "cat has:images -grumpy", "tag": "cat pictures"},
    ]
    payload = {"add": sample_rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        auth=bearer_oauth,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))

def get_stream(set):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream", auth=bearer_oauth, stream=True,
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            print(json.dumps(json_response, indent=4, sort_keys=True))

# %%
rules = get_rules()
delete = delete_all_rules(rules)
set = set_rules(delete)
get_stream(set)
# Out:
# {"data": [{"id": "1501726386079379456", "value": "dog has:images", "tag": "dog pictures"}, {"id": "1501726386079379457", "value": "cat has:images -grumpy", "tag": "cat pictures"}], "meta": {"sent": "2022-03-30T00:44:43.679Z", "result_count": 2}}
# {"meta": {"sent": "2022-03-30T00:44:45.066Z", "summary": {"deleted": 2, "not_deleted": 0}}}
# {"data": [{"value": "cat has:images -grumpy", "tag": "cat pictures", "id": "1508968437313413122"}, {"value": "dog has:images", "tag": "dog pictures", "id": "1508968437313413121"}], "meta": {"sent": "2022-03-30T00:44:46.939Z", "summary": {"created": 2, "not_created": 0, "valid": 2, "invalid": 0}}}
# 200
# {
#     "data": {
#         "id": "1508968415557566471",
#         "text": "RT @Guccitarantin0: Quick Jake the Dog sketch https://t.co/vcYwW3AdkY"
#     },
#     "matching_rules": [
#         {
#             "id": "1508968437313413121",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1508968416928927745",
#         "text": "RT @lovejoybugs: thread of tommy pictures but he\u2018s the eep cat https://t.co/7zuvNRuswt"
#     },
#     "matching_rules": [
#         {
#             "id": "1508968437313413122",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1508968421882736640",
#         "text": "RT @VBS_BAD_DOG_: \u3048\u30fc\u3001\u30ab\u30e9\u30d5\u30a7\u30b9\u304c\u660e\u65e5\u306b\u8feb\u308a\u307e\u3057\u305f\u3002\n\u3044\u3044\u306d\u3068RT\u3092\u62bc\u305b\u3070\u661f\u56db\u6765\u308b\u304b\u3082\uff1f\n#\u30d7\u30ed\u30bb\u30ab  #\u30d7\u30ed\u30b8\u30a7\u30af\u30c8\u30bb\u30ab\u30a4\n#\u30ab\u30e9\u30d5\u30a7\u30b9 #\u30ab\u30e9\u30d5\u30eb\u30d5\u30a7\u30b9\u30c6\u30a3\u30d0\u30eb https://t.co/4zxH1TmkrE"
#     },
#     "matching_rules": [
#         {
#             "id": "1508968437313413121",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1508968421244948480",
#         "text": "RT @iLVLHE91: *hoy juega per\u00fa con paraguay*\ndoja cat: https://t.co/Oiremjt7mK"
#     },
#     "matching_rules": [
#         {
#             "id": "1508968437313413122",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1508968426202710022",
#         "text": "We have been told that if we post a cat we have to say #GANGGANG or #WLTC.\n\nWhy is that? \ud83e\udd14\ud83e\udd43 https://t.co/W5hmGjwDFq"
#     },
#     "matching_rules": [
#         {
#             "id": "1508968437313413122",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1508968424080171008",
#         "text": "\u3010\u30ca\u30c1\u30e5\u30e9\u30eb\u306a\u30d9\u30fc\u30b8\u30e5\u306b\u30b7\u30a2\u30fc\u306a\u30d4\u30f3\u30af\u3011 | b-ex journal https://t.co/8L0xlgsI1g #throwcolor #tintbar #b-exjournal https://t.co/xMYvTYrkJq"
#     },
#     "matching_rules": [
#         {
#             "id": "1508968437313413122",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1508968427435737088",
#         "text": "RT @hinako_munchkin: \u3072\u306a\u3001\u8d77\u304d\u305f\uff01\n\n#\u732b #cat https://t.co/aVPviwyPKV"
#     },
#     "matching_rules": [
#         {
#             "id": "1508968437313413122",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1508968424806010880",
#         "text": "RT @cat_dot_exe: https://t.co/dYSZOu72a1"
#     },
#     "matching_rules": [
#         {
#             "id": "1508968437313413122",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1508968425892491266",
#         "text": "RT @jikyumyboo: jihoon with a dog and junkyu with a cat. they are so adorable! their love for dogs and cats \ud83d\udc97 https://t.co/YL3mx2a71J"
#     },
#     "matching_rules": [
#         {
#             "id": "1508968437313413122",
#             "tag": "cat pictures"
#         },
#         {
#             "id": "1508968437313413121",
#             "tag": "dog pictures"
#         }
#     ]
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3b567908fb05> in <module>()
#       2 delete = delete_all_rules(rules)
#       3 set = set_rules(delete)
# ----> 4 get_stream(set)
#
# <ipython-input-6-b2304df3543b> in get_stream(set)
#      59             )
#      60         )
# ---> 61     for response_line in response.iter_lines():
#      62         if response_line:
#      63             json_response = json.loads(response_line)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     802         pending = None
#     803
# --> 804         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     805
#     806             if pending is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in generate()
#     758             if hasattr(self.raw, 'stream'):
#     759                 try:
# --> 760                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761                         yield chunk
#     762                 except ProtocolError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     596         with self._error_catcher():
#     597             while True:
# --> 598                 self._update_chunk_length()
#     599                 if self.chunk_left == 0:
#     600                     break
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in _update_chunk_length(self)
#     538         if self.chunk_left is not None:
#     539             return
# --> 540         line = self._fp.fp.readline()
#     541         line = line.split(b';', 1)[0]
#     542         try:
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
