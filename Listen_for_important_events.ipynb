# %% [markdown]
# The goal of this tutorial is to introduce how to use the filtered stream and sample stream endpoints, more details can be found - https://developer.twitter.com/en/docs/twitter-api/tweets/filtered-stream/integrate/build-a-rule
#
# This code is based on https://github.com/twitterdev/Twitter-API-v2-sample-code/blob/main/Filtered-Stream/filtered_stream.py <br>
#
# The first step would be to important the required python packages.

# %%
import requests
import os
import json

# %% [markdown]
# You would need to set up the bearer token, from your twitter App developer dashboard, for secure point of entry to use the twitter API. <br>
#
# The bearer token can be found on your twitter App developer dashboard under the "keys and tokens" page of the desired twitter app, for more details check out this page - https://developer.twitter.com/en/docs/authentication/oauth-2-0/bearer-tokens <br>
#
# A secure way to use your credentials is by creating environment variables in your terminal.
#
# export 'BEARER_TOKEN'='xxxx'
#
# bearer_oauth is used for bearer_token authorization.

# %%
bearer_token = os.environ.get("BEARER_TOKEN")

def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2FilteredStreamPython"
    return r

# %% [markdown]
# You can use the sample stream endpoint to get 1% of all tweets happening on twitter. Based on these tweets you can pick up trends and popular topics among them. <br>
#
# You can access the sample stream endpoint using create_url. To get response from the end point you can use connect_to_endpoint

# %%
def create_url():
    return "https://api.twitter.com/2/tweets/sample/stream"

# %%
def connect_to_endpoint(url):
    response = requests.request("GET", url, auth=bearer_oauth, stream=True)
    print(response.status_code)
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            print(json.dumps(json_response, indent=4, sort_keys=True))
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )

# %% [markdown]
# You can use the following code to get 1% of all activity happening on twitter.

# %%
url = create_url()
timeout = 0
while True:
    connect_to_endpoint(url)
    timeout += 1
# Out:
# 200
# {
#     "data": {
#         "id": "1501726049867993089",
#         "text": "RT @kochengfess: \ud83d\udc08\u200d\u2b1b mirip emoji ini \ud83d\ude3e\ud83d\ude3e\ud83d\ude3e\ud83d\ude3e\ud83d\ude3e\ud83d\ude3e\ud83d\ude3e https://t.co/tGK7ad7BWb"
#     }
# }
# {
#     "data": {
#         "id": "1501726049842851840",
#         "text": "RT @a_t_o_p_y: https://t.co/tqv87HraNF"
#     }
# }
# {
#     "data": {
#         "id": "1501726049847382018",
#         "text": "RT @hironikaido: \u65e5\u672c\u3067\u4e00\u756a\u5acc\u3044\u3067\u3059\u3001\u6a4b\u4e0b\u5fb9\u203c\ufe0f\n\u65e5\u672c\u3084\u65e5\u672c\u4eba\u306b\u3068\u3063\u3066\u4f55\u306e\u5f79\u306b\u3082\u7acb\u305f\u306a\u3044\u6709\u76ca\u306a\u63d0\u6848\u3082\u4f55\u4e00\u3064\u7121\u3057\ud83d\udca2\n\u3053\u3044\u3064\u306f\u4e8c\u5ea6\u3068\u653f\u6cbb\u306b\u95a2\u308f\u3089\u305b\u3066\u306f\u306a\u3089\u306a\u3044\u203c\ufe0f\n#\u6a4b\u4e0b\u5fb9\u3092\u30c6\u30ec\u30d3\u306b\u51fa\u3059\u306a\n\n\u201c\u30a6\u30af\u30e9\u30a4\u30ca\u60c5\u52e2\u306e\u610f\u898b\u304c\u3042\u307e\u308a\u306b\u3072\u3069\u3059\u304e\u308b\u201d\u2026Twitter\u3067\u300e #\u6a4b\u4e0b\u5fb9\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726049843171329",
#         "text": "I\u2019m bi! https://t.co/KMewOkZq19"
#     }
# }
# {
#     "data": {
#         "id": "1501726054041456643",
#         "text": "RT @AmongUsGame: @DynamoSuperX best prof"
#     }
# }
# {
#     "data": {
#         "id": "1501726054028824578",
#         "text": "RT @sahouraxo: This is absolute \ud83d\udd25 https://t.co/4ZEX1Svwzf"
#     }
# }
# {
#     "data": {
#         "id": "1501726054041505792",
#         "text": "@Reza_L_M10 \u0639\u0631\u0628\u0646 \u062f\u06cc\u06af\u0647"
#     }
# }
# {
#     "data": {
#         "id": "1501726049834393602",
#         "text": "\u30af\u30c3\u30af\u30d1\u30c3\u30c9\u30de\u30fc\u30c8\u30a2\u30d7\u30ea\u3067\u30af\u30fc\u30dd\u30f3\u30b3\u30fc\u30c9\u3092\u9806\u756a\u306b\u5165\u529b\u3059\u308b\u30681,540\u5186\u5206\u306e\u30af\u30fc\u30dd\u30f3\u304cGET\u3067\u304d\u307e\u3059\uff01\uff01\u2460ZB5GYK\u2192\u2461STMT06\n\nhttps://t.co/QQiXM2HQM6\n#\u30af\u30c3\u30af\u30d1\u30c3\u30c9\u30de\u30fc\u30c8 #\u30af\u30c3\u30af\u30d1\u30c3\u30c9"
#     }
# }
# {
#     "data": {
#         "id": "1501726049838993409",
#         "text": "\"\ub4dc\ub514\uc5b4 \uac24\ub7ed\uc2dc\uc5d0\uc11c \uac08\uc544\ud0c8\ub54c\uc778\uac00...\n\uc544\uc774\ud3f012 pro, \ubbf8\ub2c8, \uc544\uc774\ud328\ub4dc 8, \uc5d0\uc5b44, \uc560\ud50c\uc6cc\uce586, SE, \uc560\ud50c\ud39c\uc2ac2\uc138\ub300\uae4c\uc9c0...!!\nhttps://t.co/RgGgy70qeo\n\uc571\ub4f1\uc774\uc6d4\ub4dc\uc5d0 \uc624\uc2e0\uac83\uc744 \ud658\uc601\ud569\ub2c8\ub2e4\n\n\ud30c\ud2b8\ub108\uc2a4\ud65c\ub3d9\ucee4\ubbf8\uc158 \uc9c0\uae09\ubc1b\uc744\uc218\uc788\uc74cx21a14\""
#     }
# }
# {
#     "data": {
#         "id": "1501726054033014786",
#         "text": "@azurychamah @lafm Qui\u00e9n esta prometiendo eso y no me vayan a decir que Petro y lo he escuchado bastante y no ha dicho eso."
#     }
# }
# {
#     "data": {
#         "id": "1501726049868075010",
#         "text": "jfjFtvPO https://t.co/Pn8v7p2gWL"
#     }
# }
# {
#     "data": {
#         "id": "1501726049855578114",
#         "text": "RT @AirCoinreal: [ANN] AirCash mobile is publicly available.\n\u00a0\nHello AirCoiners, the AirCash mobile is publicly available now.\n\nWe have upd\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726054024630275",
#         "text": "RT @xgostosasbr: Mais um v\u00eddeo divulgado pela Emilly Souza https://t.co/VxU4dHEnJq"
#     }
# }
# {
#     "data": {
#         "id": "1501726049838985217",
#         "text": "groove\u306e\u30e9\u30a4\u30d6\u3063\u3066\u3001\u3069\u3053\u304b\u3089\u6620\u50cf\u5316\u3055\u308c\u3066\u308b\u3093\u3060\u308d\u3002\u500b\u4eba\u7684\u306a\u30bb\u30c3\u30c8\u30ea\u30b9\u30c8\u306f\n\u300c\uff10.\u50d5\u3089\u306f\u307e\u3060\u300d\n\u306a\u3093\u3060\u3051\u3069\u306d\uff5e\u3002\n\u3042\u308c\u304c\u6d41\u308c\u59cb\u3081\u305f\u3089\u3061\u3087\u3063\u3068\u5bc2\u3057\u304f\u306a\u3063\u3061\u3083\u3046\u306e\u3082\u3042\u3063\u305f\u3051\u3069\u306d\uff5e( \u00b4\u2022\u0325 \u00a0\u032b \u2022\u0325` )"
#     }
# }
# {
#     "data": {
#         "id": "1501726049855434753",
#         "text": "@InvisibleFriens @ZeeShu17109298 @shajahanthekkil @Mohmad99005578 @felikthepirate @VHIPHON74151676 @Saumarht @luke26640294 @azanjnr21 @bay_zekk @cryptolove @SarogiPawan @chocyc27 @morgan_grenfell @Niraj2062 @jorgecastillog1 @TheYemo92 @KRISHNA79297991"
#     }
# }
# {
#     "data": {
#         "id": "1501726049868353537",
#         "text": "@ritaekimq Semangat"
#     }
# }
# {
#     "data": {
#         "id": "1501726054037213185",
#         "text": "RT @gi6543210: \u2728\u09ac\u09be\u0997\u09be\u09a8\u09bf https://t.co/GZBrBD3Ohp"
#     }
# }
# {
#     "data": {
#         "id": "1501726054049730560",
#         "text": "RT @ceyla_giveaways: $10 to 1 winner in 1 hour\n\n\u2714 RT this and Tag 1 friend in @CryptoRonnin 's \ud83d\udccc"
#     }
# }
# {
#     "data": {
#         "id": "1501726054062252036",
#         "text": "RT @Quantarts: \ud83d\udc8eBiggest Blue-chip NFT Platform!\ud83d\udc40\ud83d\udc8e\nBacked by real masterpiece paintings, an investment you can trust!! \ud83d\ude31\ud83d\ude80\nGet Whitelist: \u2935\ufe0f\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726054058115074",
#         "text": "RT @dlstjq5106: @tnr0202 \uc624\uc9c1 \uc784\uc601\uc6c5\ud558\ub294  \uacf5\uce74\uac00 \ub418\uae38\uc694 \ud83d\ude4f\n\uc568\ubc94\ub098\uc624\uace0  \ud0c0\ucee4\ubba4\ub2c8\ud2f0  \ubc30\ucc99  \uc548\ud558\uace0\n\ud568\uaed8  \uc73c\uc0e4\uc73c\uc0e4 \ud558\ub294  \ubd84\uc704\uae30 \ub9cc\ub4e4\uc5b4\uc8fc\uae38..   \uc784\uc601\uc6c5\ub9cc \uc0dd\uac01\ud558\uba74\n\uc88b\uaca0\uc5b4\uc694  \ub9ce\uc740\uac70  \uc548\ubc14\ub78c\uc694\ud83d\ude06"
#     }
# }
# {
#     "data": {
#         "id": "1501726049863929860",
#         "text": "RT @KaityFrias: 35315 #\u00e7erkezk\u00f6y  \n\u015eu hayatta imrendigim tek ki\u015fi deterjan reklam\u0131nda kendini camura at\u0131p eve gelince dayak yemeyen cocuktu\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726049855496198",
#         "text": "RT @apofissx: Who is curious? Zelda is! (\u30fb\uff40\u03c9\u00b4\u30fb) Lovely @CuriousZelda makes quite expressive poses / shapes to warm-up drawing tablet! \ud83d\udda4 htt\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726049847156736",
#         "text": "@Y0OUSEF \u0648\u0643\u0627\u0645\u0627"
#     }
# }
# {
#     "data": {
#         "id": "1501726054024884225",
#         "text": "RT @yantic__: \u3010\u4ea4\u63db\u3011 \u30cf\u30a4\u30ad\u30e5\u30fc\u5c55 \u30b3\u30ec\u30af\u30b7\u30e7\u30f3\u7f36\u30d0\u30c3\u30b8 \u7b2c8\u5f3e \u30b3\u30ec\u7f36 \u30cf\u30a4\u30ad\u30e5\u30fc\n\n\u8b72\uff5c\u5bae\u4f91 \u5f71\u5c71\n\n\u6c42\uff5c\u5b64\u722a \u7814\u78e8\n\n\u90f5\u9001 or 3/10.11\u624b\u6e21\u3057 or \u4ed9\u53f0\u624b\u6e21\u3057\n\n\u691c\u7d22\u304b\u3089\u3082\u304a\u58f0\u304c\u3051\u4e0b\u3055\u3044\u3002\n\u521d\u56de\u306e\u65b9\u306f\u30ea\u30f3\u30af\u306e\u3054\u4e00\u8aad\u304a\u9858\u3044\u81f4\u3057\u307e\u3059\u3002 https:/\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726054037454848",
#         "text": "@25250_s \u304a\u306f\u3088\u3046"
#     }
# }
# {
#     "data": {
#         "id": "1501726054024679424",
#         "text": "Did @RobbieHummel just hit us with a \u201cnice\u201d as the Nebraska/Northwestern score was deadlocked at 69? \ud83d\ude02"
#     }
# }
# {
#     "data": {
#         "id": "1501726054041325569",
#         "text": "RT @lumendoz: Toda mi solidaridad y mis  respetos para ti como periodista, amiga y MUJER. Sin duda alguna, tu cobertura fue la MEJOR."
#     }
# }
# {
#     "data": {
#         "id": "1501726054041657344",
#         "text": "\u65e5\u672c\u306e\u53f3\u6d3e\u30fb\u4fdd\u5b88\u6d3e\u306b\u3082\u300c\u5408\u6cd5\u7684\u306b\u5728\u7559\u3057\u3001\u89aa\u65e5\u7684\u306a\u5916\u56fd\u4eba\u3067\u3042\u308c\u3070\u30a6\u30a7\u30eb\u30ab\u30e0\u300d\u306e\u3088\u3046\u306a\u98a8\u6f6e\u304c\u3042\u308b\u304c\u3001\u8868\u5411\u304d\u306f\u771f\u3063\u5f53\u306a\u5546\u58f2\u3092\u3057\u3066\u3055\u3048\u3044\u308c\u3070\u3001\u30de\u30d5\u30a3\u30a2\u305d\u306e\u3082\u306e\u304b\u3001\u6f5c\u5728\u7684\u306a\u30de\u30d5\u30a3\u30a2\u4e88\u5099\u8ecd\u306e\u3088\u3046\u306a\u8f29\u3067\u3082\u30a6\u30a7\u30eb\u30ab\u30e0\u306a\u306e\u3060\u308d\u3046\u304b\u3002"
#     }
# }
# {
#     "data": {
#         "id": "1501726054058446848",
#         "text": "RT @Iyemon_jp: \uff0f\n\u3082\u3063\u3068\u304a\u3044\u3057\u3044\u3001\u6df9\u308c\u305f\u3066\u7dd1\u3078\u3002\n\u65b0\uff01 #\u4f0a\u53f3\u885b\u9580\n\uff3c\n\n\u307e\u3060\u307e\u3060\u9593\u306b\u5408\u3046\uff01\n\u65b0\u3057\u3044\u4f0a\u53f3\u885b\u95801\u30b1\u30fc\u30b9\u304c\u62bd\u9078\u3067100\u540d\u69d8\u306b\u5f53\u305f\u308b\ud83c\udf81\n\n\u5fdc\u52df\u65b9\u6cd5\n\u2460@Iyemon_jp\u3092\u30d5\u30a9\u30ed\u30fc\n\u2461\u672c\u6295\u7a3f\u3092RT\uff01\n\u203b3/14\u307e\u3067 #\u6bce\u65e5\u5fdc\u52df\nhttps://t.co\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726054041501699",
#         "text": "@trappedinazorb @chronopictures i wish it was more like divine dragon instead where its cinematic/gimmicky but easy"
#     }
# }
# {
#     "data": {
#         "id": "1501726054058115076",
#         "text": "RT @_muffinp: \u0e1b\u0e4a\u0e2d\u0e01\u0e15\u0e32\u0e41\u0e25\u0e15 \u0e08\u0e49\u0e2d\u0e19\u0e27\u0e31\u0e49\u0e22\u0e2b\u0e19\u0e31\u0e22! \u0e21\u0e31\u0e48\u0e22\u0e2d\u0e2d\u0e01\u0e40\u0e04 \u0e22\u0e07\u0e21\u0e32\u0e2b\u0e32\u0e15\u0e2d\u0e19\u0e15\u0e35\u0e09\u0e2d\u0e21\u0e01\u0e48\u0e30\u0e22\u0e31\u0e07\u0e21\u0e31\u0e48\u0e22\u0e40\u0e15\u0e2d \u0e21\u0e31\u0e48\u0e22\u0e2d\u0e2d\u0e40\u0e04!! https://t.co/qOE1odm6k4"
#     }
# }
# {
#     "data": {
#         "id": "1501726054024679427",
#         "text": "RT @Got_qs: THIS. In a learning landscape we can \u201cbend the curriculum towards who students really are\u201d. We can \u201cwork towards a horizon\u201d of\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726054054084610",
#         "text": "@perinehir83 \u00dczd\u00fc\ud83d\ude14"
#     }
# }
# {
#     "data": {
#         "id": "1501726054033117188",
#         "text": "RT @WHasko35: Check out the newest edition of the Hudson Junior High Newscast!\n\n#hudsonschools \u2066@edutopia\u2069 \u2066@EdTechFam\u2069 \u2066\u2066@DiscoveryEd\u2069  ht\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726058240004097",
#         "text": "I think I found me a keeper \ud83e\udd7a"
#     }
# }
# {
#     "data": {
#         "id": "1501726054033297410",
#         "text": "RT @livedoornews: \u3010\u8853\u5f8c2\u30ab\u6708\u3067\u3011\u907a\u4f1d\u5b50\u64cd\u4f5c\u3055\u308c\u305f\u30d6\u30bf\u306e\u5fc3\u81d3\u3092\u4eba\u4f53\u306b\u79fb\u690d\u3001\u4e16\u754c\u521d\u306e\u624b\u8853\u3092\u53d7\u3051\u305f\u7537\u6027\u304c\u6b7b\u4ea1 \u7c73\nhttps://t.co/lhVH1LJKuf\n\n\u6570\u9031\u9593\u306f\u62d2\u7d76\u53cd\u5fdc\u3082\u306a\u304f\u7d4c\u904e\u306f\u826f\u597d\u3060\u3063\u305f\u304c\u3001\u6570\u65e5\u524d\u306b\u5065\u5eb7\u72b6\u614b\u304c\u60aa\u5316\u3002\u56de\u5fa9\u306e\u898b\u8fbc\u307f\u304c\u306a\u304f\u306a\u3063\u305f\u3053\u3068\u304b\u3089\u7de9\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726054050054145",
#         "text": "RT @yumihama_ema: \u3046\u3061\u306e\u5b50 \u9b54\u6cd5\u5c11\u5973\u3061\u3083\u3093\n#\u30a4\u30e9\u30b9\u30c8 \n#illustration \n#\u30da\u30f3\u753b \n#\u7d75\u63cf\u304d\u3055\u3093\u3068\u7e4b\u304c\u308a\u305f\u3044 \n#\u6f2b\u753b\u5bb6\u5fd7\u671b\u3055\u3093\u3068\u7e4b\u304c\u308a\u305f\u3044 https://t.co/nzAGGwKEwY"
#     }
# }
# {
#     "data": {
#         "id": "1501726054062383104",
#         "text": "RT @RincnCuriosoo: T\u00f3mame una foto as\u00ed como que todo es relativo https://t.co/OKeDenxmUI"
#     }
# }
# {
#     "data": {
#         "id": "1501726054045691904",
#         "text": "@ehj03151767 I do \ud83e\udd37\u200d\u2642\ufe0f\ud83d\ude02\ud83d\ude02"
#     }
# }
# {
#     "data": {
#         "id": "1501726054028873730",
#         "text": "que mira. https://t.co/8GALX7MwRp"
#     }
# }
# {
#     "data": {
#         "id": "1501726054024880128",
#         "text": "\u725b\u30bf\u30f3\u98df\u3044\u306b\u884c\u304d\u305f\uff5e\uff5e\u3044\uff01\uff01"
#     }
# }
# {
#     "data": {
#         "id": "1501726054037487617",
#         "text": "RT @ChunRayang: \ub3c5\uc77c\uc5d0\uc11c \uc2e4\uc81c\ub85c \uc131\ub9e4\ub9e4 \ud569\ubc95\ud654\uac00 \ub41c \uc801\uc774 \uc788\uc5c8\ub294\ub370 \uadf8\ub54c\ub294 \uadf8\uc57c\ub9d0\ub85c \uc0dd \uc9c0\uc625\uc774\uc5c8\ub2e4... \ub2f9\uc2dc \ub3c5\uc77c\uc5d0\uc11c\ub294 \uc131\ud310\ub9e4 \uc5ec\uc131\ub4e4\uc758 \uc778\uad8c\uc774 \uc624\ub978\ub2e4\uace0 \uc0dd\uac01\ud588\uc9c0\ub9cc \uacb0\uacfc\ub294 \uc131\ub9e4\ub9e4 \uc2dc\uc7a5\uc5d0\uc11c \uacf5\uae09\uc774 \ub298\uc790 \uc218\uc694\uac00 \ub5a8\uc5b4\uc9c0\uace0 \uac00\uaca9\ub300\uac00 \ud3ed\ub77d-&gt; \uc0ac\ub78c\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726054062436355",
#         "text": "RT @ZelenskyyUa: Talked to my friend @JustinTrudeau about \ud83c\uddfa\ud83c\udde6\ud83c\udde8\ud83c\udde6 defense cooperation and how to increase sanctions pressure on Russia. Agreed\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726054062620672",
#         "text": "@knxbb \u5206\u304b\u308b\ud83d\ude02\u3067\u3082\u6ec5\u591a\u306b\u884c\u304b\u306a\u3044\u304b\u3089\u884c\u3063\u305f\u3089\u7206\u8cb7\u3044\u3088\u2190"
#     }
# }
# {
#     "data": {
#         "id": "1501726054053924866",
#         "text": "RT @jiro_kame: \u304a\u4e16\u8a71\u306b\u306a\u3063\u3066\u307e\u3059\u3002\u30e9\u30fc\u30e1\u30f3\u4e8c\u90ce\u4e80\u6238\u5e97\u3053\u3089\u306e\u304a\u9858\u3044\u3067\u3059\u3002 https://t.co/ZwVN3l6J26"
#     }
# }
# {
#     "data": {
#         "id": "1501726054024683524",
#         "text": "Mark Zuckerberg NAMED In Special Counsel Investigation. Accused Of Break... https://t.co/flBg4NNEwM via @YouTube"
#     }
# }
# {
#     "data": {
#         "id": "1501726054058242049",
#         "text": "RT @eiamigas: muito medo https://t.co/5HJ6DflQJv"
#     }
# }
# {
#     "data": {
#         "id": "1501726058218983427",
#         "text": "\u0646\u0648\u0651\u0631 \u0628\u0635\u064a\u0631\u062a\u064a \u064a\u0627\u0631\u0628 \u0641\u064a \u0627\u0645\u0648\u0631\u064a \u0643\u0644\u0647\u0627\ud83d\udc97."
#     }
# }
# {
#     "data": {
#         "id": "1501726054041505794",
#         "text": "RT @bookstan19: Vcs tbm concordam?? Deve ser por isso q gosto do Lucien sempre fui cadelinha do Klaus kkkkkkkkkkkkkk\n\ud83c\udfa8itswibell_art https:/\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726054028918785",
#         "text": "RT @LetyVarela: Las alianzas son importantes para seguir avanzando en el tema de #BienestarAnimal \n\nGracias por preocuparte y ocuparte por\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726054045536259",
#         "text": "\u306b\u3083\u30fc\n\u3000\u2227_,,,_\u2227 \n\u3000=\u30fb \uff4f \uff65=\u3000\u306b\u3083\u3093 \no(,_\uff55\uff55\uff89"
#     }
# }
# {
#     "data": {
#         "id": "1501726058227372040",
#         "text": "@camilalmeidar @bchartsnet @amandacdornelas Kkkkkkkkkk MANO O LUCAS \u00c9 O FAMOSO ACUMULADOR"
#     }
# }
# {
#     "data": {
#         "id": "1501726054028820486",
#         "text": "#TheWorldStandsWithUkraine https://t.co/b1nrNnFVp5"
#     }
# }
# {
#     "data": {
#         "id": "1501726054050058240",
#         "text": "RT @RY4JAH: 31\n\n-suapatt \ud83d\ude2d https://t.co/DvFd4cdvl5"
#     }
# }
# {
#     "data": {
#         "id": "1501726054050074624",
#         "text": "@epionve Kapan?"
#     }
# }
# {
#     "data": {
#         "id": "1501726054054268928",
#         "text": "RT @V234936161: \u0e23\u0e38\u0e48\u0e19\u0e43\u0e2b\u0e0d\u0e48 https://t.co/8h4wgs5MTq"
#     }
# }
# {
#     "data": {
#         "id": "1501726054049792001",
#         "text": "As\u00ed es y as\u00ed ser\u00e1. Gracias , gracias \ud83d\ude4f \ud83d\ude4f \ud83d\ude4f https://t.co/Vwzruf92m7"
#     }
# }
# {
#     "data": {
#         "id": "1501726058223226882",
#         "text": "RT @totalcristiano: https://t.co/ipl7VshZgl"
#     }
# }
# {
#     "data": {
#         "id": "1501726058248380419",
#         "text": "@karlie_u @DShep150 No, how about we helped you realize your potential future and you opened your eyes."
#     }
# }
# {
#     "data": {
#         "id": "1501726054049665030",
#         "text": "RT @OwenDoran48: We are seeing disproportionate  number of pregnant women with COVID coming through ED at the moment. Often unvaccinated, o\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726054054264834",
#         "text": "\ud5e4 \uc774\uc81c\ubcf4\ub2c8 48\ubd80\ub124"
#     }
# }
# {
#     "data": {
#         "id": "1501726058223063043",
#         "text": "RT @arujtur: Rt,\u0e2b\u0e32\u0e40\u0e1e\u0e37\u0e48\u0e2d\u0e19\u0e04\u0e23\u0e31\u0e1a\u0e08\u0e19\u0e40\u0e1e\u0e37\u0e48\u0e2d\u0e19\u0e21\u0e32\u0e01\ud83e\udd72 #talkximg"
#     }
# }
# {
#     "data": {
#         "id": "1501726058231451653",
#         "text": "RT @bunnysuitglitch: i'm pretty sure when people when people say they wanna put their legs between Glitches thighs they're not thinking abo\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726058239782913",
#         "text": "RT @MadridXtra: The celebration in the locker room, after the game.  https://t.co/LYWvCQF3tZ"
#     }
# }
# {
#     "data": {
#         "id": "1501726058239954945",
#         "text": "@RatioPerfeito Corre\u00e7\u00e3o a Anitta deu um ratio no bolsonaro\n\nhttps://t.co/Om9kIGurrt"
#     }
# }
# {
#     "data": {
#         "id": "1501726058227372032",
#         "text": "RT @abdalafarah: MBL, esgoto do Brasil! \n\nO jornal franc\u00eas Le Figaro noticiou a viagem canalha do Artur do Val (Dep do PODEMOS e MBL) e Ren\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726058223226885",
#         "text": "RT @18Insta_gram: \u2728\u09ac\u09be\u0997\u09be\u09a8\u09bf https://t.co/YY4BdPcuCr"
#     }
# }
# {
#     "data": {
#         "id": "1501726058244354049",
#         "text": "\u300e\u66f2\u308a\u89d2\u300f\n#\u795e\u5409\u62d3\u90ce \n\u4eba\u751f\u306e\u66f2\u308a\u89d2\u3092\u8fce\u3048\u305f\u4e2d\u9ad8\u5e74\u3092\u63cf\u304f17\u7bc7  \u2015\u2015\u4e16\u9593\u3068\u3044\u3046\u3082\u306e\u306f\u304a\u305d\u308d\u3057\u3044\u306a\u2026\u2026\u5ead\u3092\u3061\u3087\u3063\u3068\u4f5c\u308a\u5909\u3048\u308c\u3070\u3001\u3069\u3053\u304b\u304a\u304b\u3057\u3044\u3068\u601d\u308f\u308c\u308b\u3057\u3001\u4ed6\u611b\u306e\u306a\u3044\u7d75\u3092\u63cf\u3051\u3070\u5909\u614b\u6271\u3044\u2026\n\u8cb7\u3046 : https://t.co/TReQa1A0jA\n\u501f\u308a\u308b : https://t.co/CLwP7ccZ0d\n\u6e2f\u533a\u7acb\u56f3\u66f8\u9928 \u6240\u8535\u9928 : \u9ad8\u8f2a"
#     }
# }
# {
#     "data": {
#         "id": "1501726058235985922",
#         "text": "MINTIA SPECIAL MOVIE https://t.co/Wz24p3MXpu @YouTube\u3088\u308a"
#     }
# }
# {
#     "data": {
#         "id": "1501726058235985920",
#         "text": "\u4f53\u91cd\u306f3.5kg\u6e1b\u3063\u3066\u305f\u3002\n\u3053\u308c\u306f\u826f\u3044\u5909\u5316\u304b\u306e\u304b\u60aa\u3044\u5909\u5316\u306a\u306e\u304b\u3002"
#     }
# }
# {
#     "data": {
#         "id": "1501726058231574532",
#         "text": "@DuaneHunt15 @nmichael32 @seanspicer Duane that is not a reasonable comparison. The truckers are paying for their fuel out of their own pockets while the democrats are either using tax dollars or constituent money to fuel the buses."
#     }
# }
# {
#     "data": {
#         "id": "1501726058227265536",
#         "text": "We could\u2019ve been superstars"
#     }
# }
# {
#     "data": {
#         "id": "1501726058252488705",
#         "text": "RT @realmadrid: \ud83d\udc9c \u00a1SIMPLEMENTE GRACIAS, #RMFANS! \ud83d\udc9c https://t.co/u6KUhljkFK"
#     }
# }
# {
#     "data": {
#         "id": "1501726058235797506",
#         "text": "@BenisKen https://t.co/mc5Lvt1h5N"
#     }
# }
# {
#     "data": {
#         "id": "1501726058231611394",
#         "text": "RT @AlertaNews24: \ud83c\uddf7\ud83c\uddfa | AHORA: La divisi\u00f3n de juegos de Sony suspende las exportaciones a Rusia."
#     }
# }
# {
#     "data": {
#         "id": "1501726058231767041",
#         "text": "\u3044\u3044\u51fa\u6765\u3060\u3068\u601d\u3063\u3066\u305f\u3051\u3069\u3001\u3046\u3063\u304b\u308a\u76f4\u7dda\u4e00\u6c17\u53d6\u308a\u5fd8\u308c\u3066\u305f...\u4f5c\u308d\u76f4\u3057\u3060\u3002 https://t.co/a9uq8GzpmC"
#     }
# }
# {
#     "data": {
#         "id": "1501726058223050752",
#         "text": "RT @_springroll_: \uc548\ub155\ud558\uc138\uc694 \uc5ec\ub7ec\ubd84!!! \uc6b0\ub9ac\uc758 \uc758\uc9c0\uc640 \uc9d1\ub2e8\uc9c0\uc131\uc744 \ubcf4\uc5ec\uc904 \ub54c\uac00 \uc654\uc2b5\ub2c8\ub2e4\ud83d\udd25\ud83d\udd25 \uc774 \ud2b8\uc717 \ud0c0\ub798\ub85c \uc774\ubc88 \uc815\uad8c\uc5d0 \ud070 \ud53c\ud574\ub97c \uc785\uc744 \uc57d\uc790\ub4e4\uc744 \uc9d1\uc911\uc801\uc73c\ub85c \uc9c0\uc6d0\ud558\ub294 \ub2e8\uccb4\ub4e4\uc744 \uc18c\uac1c\ud574\uc8fc\uc2dc\uba74 \uac10\uc0ac\ud558\uaca0\uc2b5\ub2c8\ub2e4! \uc800\ub3c4 \uc544\ub294\ub9cc\ud07c \ucd5c\ub300\ud55c \uc368\ubcfc\uac8c\uc694,\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726058240163841",
#         "text": "@karupassu0818 \u3042\u308a\u304c\u3068\u3067\u3054\u3056\u308b\u306e\u5dfb\ud83e\udd77\u30ab\u30eb\u3055\u3093\u4f11\u307f\u3060\u3063\u3051\uff01"
#     }
# }
# {
#     "data": {
#         "id": "1501726062430109700",
#         "text": "n corro mais atr\u00e1s, n mando mais msge tmb n fa\u00e7o mais quest\u00e3o."
#     }
# }
# {
#     "data": {
#         "id": "1501726058231513090",
#         "text": "Apenas se viene a dar cuenta que el Petrismo es peor que el uribismo https://t.co/7RC14HPqa3"
#     }
# }
# {
#     "data": {
#         "id": "1501726058231463937",
#         "text": "RT @DelhiDvta: 9th day Live Delhi Vocational Trainers\ud83d\ude2d huge Dharna pradarshan at kejriwal Niwas, civil line in Delhi on 9 March 2022 regard\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726058240155649",
#         "text": "@jiminiehauls koo morning liza batumvakal"
#     }
# }
# {
#     "data": {
#         "id": "1501726058235654145",
#         "text": "RT @chewy_kook: #TZUYU : She's literally the definition of \"beauty\"\ud83d\ude33 https://t.co/Hr56tsXLKp"
#     }
# }
# {
#     "data": {
#         "id": "1501726058231787522",
#         "text": "RT @mollyfantasy_of: \uff3c\u5f53\u793e\u9650\u5b9a \uff03\u6771\u4eac\u30ea\u30d9\u30f3\u30b8\u30e3\u30fc\u30ba \u30d7\u30e9\u30a4\u30ba \u30b3\u30f3\u30d7\u30ea\u30fc\u30c8\u30bb\u30c3\u30c8\u304c\u5f53\u305f\u308b\ud83d\udd25\uff0f\n\u518d\u767b\u5834\u8a18\u5ff5\ud83d\udc4a\u2757\ufe0f\n\u2460@mollyfantasy_of\u3092\u30d5\u30a9\u30ed\u30fc\n\u2461\u3053\u306e\u30c4\u30a4\u30fc\u30c8\u3092RT\n\u62bd\u9078\u30673\u540d\u3055\u307e\u306b\u5f53\u793e\u9650\u5b9a\u30d7\u30e9\u30a4\u30ba \u30b3\u30f3\u30d7\u30ea\u30fc\u30c8\u30bb\u30c3\u30c8\u3092\u30d7\u30ec\u30bc\u30f3\u30c8\ud83c\udf81\n\n3/\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726058248343555",
#         "text": "RT @Martinpdisalvo: me caga el dia y la semana saber que messi esta triste"
#     }
# }
# {
#     "data": {
#         "id": "1501726058219020291",
#         "text": "@BobbyBananasNFT Maybe the start of a crypto rally today, fingers crossed"
#     }
# }
# {
#     "data": {
#         "id": "1501726058235981824",
#         "text": "RT @chartdata: .@BTS_twt has now earned over 3 billion on-demand streams worldwide in 2022, the #1 most streamed group."
#     }
# }
# {
#     "data": {
#         "id": "1501726058248564740",
#         "text": "RT @PALITAPATCHA702: \u0e04\u0e34\u0e14\u0e16\u0e36\u0e07\u0e17\u0e38\u0e01\u0e27\u0e31\u0e19 \n\nAll I do is think of you\n#\u0e04\u0e34\u0e14\u0e16\u0e36\u0e07\u0e40\u0e2a\u0e21\u0e2d\u0e41\u0e21\u0e49\u0e44\u0e21\u0e48\u0e44\u0e14\u0e49\u0e40\u0e08\u0e2d\n@peckpalit\n#\u0e40\u0e1b\u0e4a\u0e01\u0e1c\u0e25\u0e34\u0e15\u0e42\u0e0a\u0e04\n#PeckPaLitChoke"
#     }
# }
# {
#     "data": {
#         "id": "1501726058227572736",
#         "text": "@Nordic_Whales #metaces"
#     }
# }
# {
#     "data": {
#         "id": "1501726058252419075",
#         "text": "RT @rupasubramanya: Is this the right look, like you're a bunch of school kids at a picnic as the world stands at the brink of a devastatin\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726062434209796",
#         "text": "Kylian il a mang\u00e9 1 comeback et une remontada...\n\n#experience"
#     }
# }
# {
#     "data": {
#         "id": "1501726062417481728",
#         "text": "@PPTeamRafa Ecuador \ud83d\ude22"
#     }
# }
# {
#     "data": {
#         "id": "1501726058244018176",
#         "text": "RT @TrophyXpose: \u2018Once in a lifetime\u2019 wolverine sighted in Yellowstone by father and daughter, 9, is one of just 6 of the 30lb animals - wh\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726058239823876",
#         "text": "RT @HardDriveMag: Entry Level Dungeon Still Requires 3-5 Years of EXP\n\nhttps://t.co/J6TEaZf6aP"
#     }
# }
# {
#     "data": {
#         "id": "1501726062425690114",
#         "text": "RT @0204chibuta: \u677e\u6f64\u3055\u3093\u306e\u8a18\u61b6\u529b\u306f\u3059\u3054\u3044\u306e\u3088 \u4e00\u5ea6\u304a\u4ed5\u4e8b\u3092\u3054\u4e00\u7dd2\u3057\u305f\u65b9\u306f\u899a\u3048\u3066\u3044\u308b\u304b\u3089\n\u3044\u3064\u3001\u3068\u308f\u304b\u308c\u3070\u3059\u3050\u306b\u601d\u3044\u51fa\u305b\u308b\u306e\u3067\u3059\ud83d\ude06\ud83d\udc4d\n\n#\u30ce\u30d6\u30ca\u30ab\u306a\u3093\u306a\u3093\u6625\u306e2\u6642\u9593SP\n#\u3068\u306a\u308a\u306e\u30c1\u30ab\u30e9\n#\u677e\u672c\u6f64"
#     }
# }
# {
#     "data": {
#         "id": "1501726058248167440",
#         "text": "RT @PNATION_LOUD: [\ud83c\udfa5] \n\u2018\ud32c \ucd94\ucc9c \uace1 \ubbf8\uc158\u2019 P NATION \ud300, \ud638\ud761 \ucc99\ucc99! \uba4b\uc9c4 \ud300 \ubb34\ub300 \u2018\uc6c0\uc9c1\uc5ec\u266c\u2019 \n(\ucd9c\ucc98 : LOUD | \ub124\uc774\ubc84TV) \n\n\ud83d\udcce https://t.co/xEdAHoWTD5\n\n#TeamPnation\ud83c\udfc1 \n#\ub77c\uc6b0\ub4dc\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726058235969536",
#         "text": "4600\u66f2\u4f5c\u3063\u3066\u6b4c\u3046\u304b\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726062417485829",
#         "text": "@Dimoo109 \u0648\u0627\u0635\u0644\u0627 \u0645\u062a\u0633\u062a\u0646\u0627\u0634 \u0645\u0646 \u0627\u0644\u0627\u062c\u062a\u0645\u0627\u0639 \u062f\u0627 \u0627\u064a \u062d\u0627\u062c\u0647 \u0645\u0641\u064a\u062f\u0647 \u0647\u064a\u0643\u0648\u0646 \u0641\u064a\u062f\u064a\u0648 \u0647\u0631\u064a \u0641\u0627\u0636\u064a \u0643\u0644\u0639\u0627\u062f\u0647 \ud83d\ude05"
#     }
# }
# {
#     "data": {
#         "id": "1501726062425907201",
#         "text": "RT @comradeaux: If Reagan were alive today and had the exact same policy positions as he had in the 80s but just occasionally tweeted shit\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726058244157446",
#         "text": "\"maybe hes just underground\" MOTOKI \ud83d\ude2d\ud83d\ude2d"
#     }
# }
# {
#     "data": {
#         "id": "1501726062421577728",
#         "text": "D-DAY BTS PERMISSION TO DANCE ON STAGE - SEOUL 2022 @BTS_twt\n\n#BTS\n#BTSARMY\n#\ubc29\ud0c4\uc18c\ub144\ub2e8\n#PTD_ON_STAGE_SEOUL\n#\uc6b0\ub9ac\ud568\uaed8\ub77c\uba74_\ud5c8\ub77d\uc740\ud544\uc694\uc5c6\uc5b4"
#     }
# }
# {
#     "data": {
#         "id": "1501726062438658050",
#         "text": "RT @BBechu_: \uc774\ubd84 03\uc774\ub77c\ub294\ub514...? \ub760\ub3d9\uac11\ub3c4 \uc544\ub2c8\uace0 \uc138\uae30\ub3d9\uac11...\uc774\ub124...."
#     }
# }
# {
#     "data": {
#         "id": "1501726062413324294",
#         "text": "@osanpo1030 \n\u3054\u53c2\u52a0\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3057\u305f\uff01\n\n\u3010\u62bd\u9078\u306e\u7d50\u679c\u306f\u2026\u3011\n\u306f\u305a\u308c\u3067\u3059\u2026\u3054\u3081\u3093\u306a\u3055\u3044\ud83d\ude22\n\n3/13\u307e\u3067\u6bce\u65e5\u958b\u50ac\u3057\u3066\u3044\u307e\u3059\u306e\u3067\u3001\u660e\u65e5\u3082\u305c\u3072\u30c1\u30e3\u30ec\u30f3\u30b8\u3057\u3066\u304f\u3060\u3055\u3044\u306d\ud83c\udf38\n\n\u25bcDL\u306f\u3053\u3061\u3089\u25bc\nhttps://t.co/gcKlkq63hq\n\n#\u653e\u7f6e\u5c11\u5973\n#Love\u653e\u7f6e\u5c11\u5973 https://t.co/6SkHrPNI2N"
#     }
# }
# {
#     "data": {
#         "id": "1501726062434160640",
#         "text": "\ub098 \uc624\ub298 \ub0b4\ub0b4 \uac1c\ud45c\ubc29\uc1a1 \ubcf4\ub290\ub77c \uc77c \ubabb\ud558\uace0 \uc800\ub141\ubd80\ud134 \uc220 \uacc4\uc18d \ub9c8\uc168\ub2e4 \uce5c\uad6c\ub4e4\uc774\ub791 \uc808\ub9dd\uacfc \uc560\ub3c4\uc640 \ud55c\uc228\uc73c\ub85c \uc2dc\uac04 \ubcf4\ub0c8\ub294\ub370 \uadf8\ub798\ub3c4 \ub098 \uc2ec \ubf51\uc740 \uac78 \ud6c4\ud68c\ud558\uc9c0\ub3c4 \uc54a\uace0 \uc624\ub298\uc744 \ub0a0\ub9b0 \uac83\ub3c4 \ud6c4\ud68c\ud558\uc9c0 \uc54a\uc544 \ub0b4\uc77c\ub3c4 \uc798 \uc0b4\uac70\uc57c \uc874\ub098 \uc5f0\uad6c\ud560\uac70\uc57c. . . \uc874\ubc84 \uc0dd\uc874 \ud560\uac70\uc57c"
#     }
# }
# {
#     "data": {
#         "id": "1501726062417383425",
#         "text": "RT @ladyincrypto: $75 GIVEAWAY ~ 6 HOURS \u23f3 \n\n($50)\n- RT &amp; Follow @QuickBuckToken + RT \ud83d\udccc \n\n(+$25)\n- Tag 3 friends on their \ud83d\udccc"
#     }
# }
# {
#     "data": {
#         "id": "1501726062451085314",
#         "text": "RT @PedroRonchi2: Refinaria privatizada vende gasolina 27,4% mais cara do que a Petrobras, mas a privatiza\u00e7\u00e3o da Eletrobras vai baixar a co\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726062425919496",
#         "text": "RT @cheeseraven11: \u201cwe can always tell\u201d the woman waxing me just asked if I got a c-section lol"
#     }
# }
# {
#     "data": {
#         "id": "1501726062434304002",
#         "text": "RT @decodejar: Let's see if the fed makes the same missteps. Just one week to find out \ud83e\udd1e"
#     }
# }
# {
#     "data": {
#         "id": "1501726062434267140",
#         "text": "RT @IndirectasRock: Me merezco estar bien y ser feliz."
#     }
# }
# {
#     "data": {
#         "id": "1501726062421880832",
#         "text": "RT @imo_pi_pi: \u3010\u305d\u306e\u5834\u3067\u5f53\u305f\u308b\u2757\ufe0f\u3011\n\u30d7\u30ec\u30bc\u30f3\u30c8\u4f01\u753b267\u56de\u76ee\ud83c\udf81\n\n1\u65e51\u4eba\u3001\u5fdc\u52df\u3068\u540c\u6642\u306b\u5f53\u9078\u8005\u3078DM\u3092\u9001\u308a\u307e\u3059\uff01\n\n\u5f53\u9078\u8005\u306f\u305d\u306e\u65e5\u306b\u5f53\u9078\u5831\u544a\u30c4\u30a4\u30fc\u30c8\u3092\u3057\u306a\u3044\u3067\u304f\u3060\u3055\u3044\u306d\ud83e\udd2b\n\n\ud83c\udf60\u719f\u6210\u671f\u95933\u30f6\u6708\n\ud83c\udf60\u7cd6\u5ea650\u5ea6\u4ee5\u4e0a\n\u6975\u871c\u719f\u6210\u713c\u304d\u828b\u30921\u540d\u69d81.5kg\u5165\u308a\u30d7\u30ec\u30bc\u30f3\u30c8\u2728\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726062434144256",
#         "text": "RT @Dennys_PR: 3\u67088\u65e5\u304b\u3089\u30c7\u30cb\u30fc\u30ba\u306e\u30e1\u30cb\u30e5\u30fc\u306f\u5927\u5e45\u30ea\u30cb\u30e5\u30fc\u30a2\u30eb\u2728\n\u65e5\u9803\u306e\u611f\u8b1d\u3092\u8fbc\u3081\u3066\u7dcf\u52e250\u69d8\u306b1000\u5186\u5206\u306e\u30c7\u30cb\u30fc\u30ba\u304a\u98df\u4e8b\u5238\u304c\u5f53\u305f\u308b\u30ad\u30e3\u30f3\u30da\u30fc\u30f3\u5b9f\u65bd\u4e2d\ud83c\udf81\ud83c\udf89\n\n\ud83c\udf8a\u53c2\u52a0\u65b9\u6cd5\ud83c\udf8a\n\u2460@Dennys_PR\u3092\u30d5\u30a9\u30ed\u30fc\n\u2461\u3053\u306e\u6295\u7a3f\u30923/10 11:59\u307e\u3067\u306bRT\n\u2462\u7d50\u679c\u306e\u30ea\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726062438277120",
#         "text": "@KofmanMichael @RealBirdLawyer https://t.co/mg0kksQX3S"
#     }
# }
# {
#     "data": {
#         "id": "1501726062421721090",
#         "text": "PSYCHONAUTS 2 || PART 2 https://t.co/nkZWZfSLGR"
#     }
# }
# {
#     "data": {
#         "id": "1501726062434299907",
#         "text": "@dagvy_ Es que la gomas son feas."
#     }
# }
# {
#     "data": {
#         "id": "1501726062429949952",
#         "text": "@lljeneo @hwangiyejy kOTAK."
#     }
# }
# {
#     "data": {
#         "id": "1501726062421889025",
#         "text": "\ud83c\udf1f\ubd04\uc5d0\ub3c4 \ud6a8\ub3c4\ud558\uae30\ub85c~ \uace0\ub824\uc758 \ucda9\uc2e0\uc774\uc790 \ud6a8\uc790\uc600\ub358  \ud3ec\uc740 \uc815\ubabd\uc8fc \uc120\uc0dd\uc758 \uc0dd\uac00\ub97c \ub3cc\uc544\ubcf4\uba70~ \ud83d\udccd\uc704\uce58 : \ud3ec\uc740\uc815\ubabd\uc8fc \uc0dd\uac00(\uc601\ucc9c\uc2dc \uc784\uace0\uba74 \ud6a8\uc790\ub85c 342) \ud3ec\uc740\uc815\ubabd\uc8fc \uc720\ud5c8\ube44(\uc601\ucc9c\uc2dc \uc784\uace0\uba74 (\ucd9c\ucc98 : \uc601\ucc9c\ub137 \u2606 .. | \ube14\ub85c\uadf8) https://t.co/Cz1JXFP4j6"
#     }
# }
# {
#     "data": {
#         "id": "1501726062434295813",
#         "text": "RT @bindokuzyuz: \u0623\u062a\u0639\u0631\u0641\u0648\u0646 \u0645\u0639\u0646\u0649 \u063a\u064a\u0631\u064a \u060c \u0628\u064a\u0622\u062e\u0630\u0647\u0627 \u0648\u0634\u0644\u0648\u0646\n\n\u0646\u0648\u0646 \u0627\u0644\u0633\u0639\u0648\u062f\u064a\u0629 \u0648\u0627\u0644\u062e\u0644\u064a\u062c   MK80\n\n\u0639\u0648\u062f \u0645\u064a\u0644\u0627\u0646\u0648   B18"
#     }
# }
# {
#     "data": {
#         "id": "1501726062438281217",
#         "text": "@AngParlantsOOC Ahora si podroa sentirme personalmente ofendido uwu"
#     }
# }
# {
#     "data": {
#         "id": "1501726062450987008",
#         "text": "\u0628\u0645\u0648\u062a\u062a\u062a \u0645\u0646 \u0627\u0644\u0636\u062d\u0643\ud83d\ude2d\ud83d\ude2d\ud83d\ude2d\ud83d\ude2d\ud83d\ude2d #\u0639\u0645\u0631_\u0628\u0646_\u0647\u0630\u0627\u0644 https://t.co/8mPga1NhkA"
#     }
# }
# {
#     "data": {
#         "id": "1501726062434463750",
#         "text": "\u4fdd\u5b89\u691c\u67fb\u3067\u30b4\u30cd\u308b\u306e\u3001\u30c6\u30ed\u72af\u6271\u3044\u3057\u3066\u3044\u3044\u3060\u308d"
#     }
# }
# {
#     "data": {
#         "id": "1501726062450982915",
#         "text": "@ordinaryethical @thegirlBJ https://t.co/N6vJwFFCOH"
#     }
# }
# {
#     "data": {
#         "id": "1501726062434267139",
#         "text": "RT @vinijr: INOLVIDABLE!!!! \ud83e\udd0d\ud83e\udd0d\ud83e\udd0d https://t.co/lFJAGstQX8"
#     }
# }
# {
#     "data": {
#         "id": "1501726062430011394",
#         "text": "https://t.co/T5zRYik4FE"
#     }
# }
# {
#     "data": {
#         "id": "1501726062451036163",
#         "text": "RT @funianime: \u2728 Hoy cumple a\u00f1os el actor de doblaje @Hektorestrada \ud83c\uddf2\ud83c\uddfd\n\ud83e\udd73\ud83c\udf88\u00a1Muchas felicidades!\ud83c\udf88\ud83e\udd73 https://t.co/4ws2OJsV3f"
#     }
# }
# {
#     "data": {
#         "id": "1501726062434078722",
#         "text": "@MeMeaw_K @BamBam1A @BAMBAMxABYSS @GOT7Official MORNING BAMBAM\ud83d\ude1a\n\n#SlowMo #WhoAreYou \n#BamBamMelting_RELEASE  @BamBam1A \n@BAMBAMxABYSS"
#     }
# }
# {
#     "data": {
#         "id": "1501726062446886912",
#         "text": "RT @Houndsaint: Gilded judas print \ud83d\udc51 https://t.co/C4pNuSlfSa"
#     }
# }
# {
#     "data": {
#         "id": "1501726062417526788",
#         "text": "A veces los ba\u00f1os p\u00fablicos pueden ser inc\u00f3modos, pero siempre dejar\u00e1n una que otra an\u00e9cdota divertida para contar. @marcosimu y @Cumparini desclasifican sus historias en sanitarios compartidos en este nuevo episodio de #EstoNoEsUnPodcast: https://t.co/QFY5vEtkkM \ud83c\udfa7 https://t.co/e8WGLgs1dY"
#     }
# }
# {
#     "data": {
#         "id": "1501726062442692609",
#         "text": "RT @TGzeiro: vamos respeitar pf \ud83d\ude4f https://t.co/dVnddC5rrR"
#     }
# }
# {
#     "data": {
#         "id": "1501726062434484225",
#         "text": "\uc65c.,\ub2e4 \ubcc4\ub8e8\uc9c0?? \ub8e8\uc2dc\uac00 \ub108\ubb34 \ub808\uc804\ub4dc\ub85c \ub098\uc640\uc11c \uadf8\ub7f0\uac00 \uba3c\uac00..."
#     }
# }
# {
#     "data": {
#         "id": "1501726062438494209",
#         "text": "@InvisibleFriens @soogyon @Aravind43440380 @richfromCrypt0 @adellacardoso @sloan_0001 @Leandro37290461 @Yaser__1985 @jenfullymade @joshdschneider @jingdt1978 @Ratmando32 @vin_b_ @Aguskur88888 @Deepminder001 @Help_ukraine__ @akamine109 @kamikze_zero"
#     }
# }
# {
#     "data": {
#         "id": "1501726062447071235",
#         "text": "RT @HwanniePromotes: $75 || 1,05 JT in 5 HOURS\n\nRT &amp; Follow @KingdomRaids"
#     }
# }
# {
#     "data": {
#         "id": "1501726062442848256",
#         "text": "RT @woodz_ZA: 2014                             2022 https://t.co/l040eLtCL5"
#     }
# }
# {
#     "data": {
#         "id": "1501726062446661632",
#         "text": "RT @dreamistae: \ud83d\udcf8 Taetae smile started my new day #v #taehyung #BTSV #BTS #PTD_ON_STAGE_SEOUL https://t.co/TgZBsAqRZm"
#     }
# }
# {
#     "data": {
#         "id": "1501726066616180736",
#         "text": "@metarobox Nice project and congratulations to the team for their efforts and dedication and highly appreciated the visionary thought of the projector and it will create history \u30b3\u30eb\u30cait will go to moon"
#     }
# }
# {
#     "data": {
#         "id": "1501726066645389313",
#         "text": "@tun_lh @artists_100 \u0631\u0648\u0639\u0629\ud83d\udc9c\ud83d\udc9c\ud83d\udc9c"
#     }
# }
# {
#     "data": {
#         "id": "1501726066632802305",
#         "text": "RT @kirbyssmart: @CarolinaCardEx1 Got to have lunch with Phil Niekro on my 9th birthday. He was the nicest man. https://t.co/GeqfacD1ic"
#     }
# }
# {
#     "data": {
#         "id": "1501726062446788610",
#         "text": "Can\u2019t wait to see how many Pam Anderson\u2019s are oot this halloween, tbh might join them"
#     }
# }
# {
#     "data": {
#         "id": "1501726066645377024",
#         "text": "comprei livros ,nunca fui triste"
#     }
# }
# {
#     "data": {
#         "id": "1501726066637180929",
#         "text": "RT @Marvin_Inu: @elonmusk Hey @elonmusk, how\u2019s $Marvin? https://t.co/lpB7iydoVJ"
#     }
# }
# {
#     "data": {
#         "id": "1501726066616184832",
#         "text": "\u304a\u30fc\u3044\u304a\u3044\u304a\u3044"
#     }
# }
# {
#     "data": {
#         "id": "1501726066620387329",
#         "text": "RT @yamryuu: Sa\u00fadem o reizinho. \n\u3081\u3061\u3083\u53ef\u611b\u3044\u3058\u3083\u3093!\n#\u738b\u69d8\u30e9\u30f3\u30ad\u30f3\u30b0 \n#\u30b3\u30b9\u30d7\u30ec https://t.co/OTdiq0Uh2q"
#     }
# }
# {
#     "data": {
#         "id": "1501726066641371139",
#         "text": "\ub300\uadf9\uad6d\uc774 \uc2ed\uc774\uad6d\uc911\uc5d0 \uc81c\uc77c \ucd94\uc6b4\ub098\ub77c\ub77c\uba74 \uc81c\uc77c \ub354\uc6b4\ub098\ub77c\ub3c4 \uc788\uaca0\ub124? \ud64d\ud76c\ud55c\ud14c \ubb3c\uc5b4\ubd10\uc57c\uaca0\ub2e4!"
#     }
# }
# {
#     "data": {
#         "id": "1501726066628603907",
#         "text": "RT @AUTrojansFB: Excited to welcome @CatamountsFB and @TNTechFootball to the first-ever mega camp is South Carolina! #L23DtheCHARGE https:/\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726066645381122",
#         "text": "@KyleClark @Clerk_Peters She. Is. Not. Eligible. 2B. Secretary. Of. State."
#     }
# }
# {
#     "data": {
#         "id": "1501726070839644162",
#         "text": "Arrumei meu quarto e deu maior sensa\u00e7\u00e3o de paz \ud83d\ude4c\ud83c\udfff"
#     }
# }
# {
#     "data": {
#         "id": "1501726066628435968",
#         "text": "RT @kakitama: \u201d\u7206\u767a\u524d\u30013\u53f7\u6a5f\u306e\u683c\u7d0d\u5bb9\u5668\u30d9\u30f3\u30c8\u306b\u3088\u3063\u3066\u6392\u51fa\u3055\u308c\u305f\u653e\u5c04\u6027\u7269\u8cea\u304c\u6d41\u308c\u8fbc\u307f\u30014\u53f7\u6a5f\u306e\u539f\u5b50\u7089\u5efa\u5c4b\u306b\u306f\u4eba\u304c\u7acb\u3061\u5165\u308c\u306a\u3044\u72b6\u614b\u3060\u3063\u305f\u3002\u30b3\u30f3\u30af\u30ea\u30fc\u30c8\u6ce8\u5165\u7528\u306e\u7279\u6b8a\u8eca\u4e21\u3092\u9060\u9694\u64cd\u4f5c\u3057\u3001\u71c3\u6599\u30d7\u30fc\u30eb\u306b\u51b7\u5374\u6c34\u3092\u6ce8\u5165\u3067\u304d\u305f\u306e\u3082\uff14\u53f7\u6a5f\u306e\u7206\u767a\u304c\u3042\u3063\u305f\u304b\u3089\u306b\u4ed6\u306a\u3089\u306a\u3044\u3002\u201d"
#     }
# }
# {
#     "data": {
#         "id": "1501726070822821888",
#         "text": "Buen d\u00eda extra\u00f1o a Nam Taehyun"
#     }
# }
# {
#     "data": {
#         "id": "1501726066624192515",
#         "text": "como le mira el culo el de atr\u00e1s jajajajajajajja yo en el espejo las 24 horas del d\u00eda https://t.co/u7drHleNQr"
#     }
# }
# {
#     "data": {
#         "id": "1501726066637172738",
#         "text": "RT @RippleXrpie: Listen to Mr. Garlinghouse and just realize for a moment what a powerful asset you are holding! #XRP https://t.co/ZXvuuwFy\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726066620375042",
#         "text": "@Bitcoinsensus https://t.co/gIwMMwidlL        \n Worlds most powerfull SHIB     #Shumo #Shiba #ETH #100x\n\nDon't miss the chance to be a billionaire. Keep on grinding! DON'T STOP! Shumo is here. \ud83d\ude80\ud83d\ude80\ud83d\ude80\ud83d\udd25"
#     }
# }
# {
#     "data": {
#         "id": "1501726066615808001",
#         "text": "RT @_imocchi_: \uff12\u65e5\u30671\u540d\u306b\u5f53\u305f\u308b\ud83c\udf81\u7cd6\u5ea650\u5ea6\u4ee5\u4e0a\u306e\u7d76\u54c1\u713c\u304d\u828b\ud83c\udf60\n\n\ud83d\ude0d\u5927\u597d\u8a55\u4f01\u753b\u7b2c40\u6bb5\ud83d\ude0d\n\n\u3010\u672c\u683c\u719f\u6210\u713c\u304d\u828b1\uff4bg\u3011\n\n\u26a1\u30d7\u30ec\u30bc\u30f3\u30c8\u26a1\n\n\u5fdc\u52df\u306f\u7c21\u5358\ud83c\udf80\n\u30fb\u3053\u306e\u30a2\u30ab\u30a6\u30f3\u30c8 \uff20_imocchi_\u3092\u30d5\u30a9\u30ed\u30fc\n\u30fb\u3053\u306e\u30c4\u30a4\u30fc\u30c8\u3092RT\ud83c\udfc3\u200d\u2642\ufe0f\n\n\u671f\u9650\u306f\u5076\u6570\u65e5\u306e23:59\u307e\u3067\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726066636951557",
#         "text": "Five minutes in and I'm already a big Marryanne fan. How can you not like her? #Survivor #Survivor42"
#     }
# }
# {
#     "data": {
#         "id": "1501726066611978240",
#         "text": "RT @DtimesDrama: \u3042\u306e\u97f3\u697d\u304c\u3088\u307f\u304c\u3048\u308b\u4e88\u544a\u7de8\u304c\u5168\u4e16\u754c\u89e3\u7981\uff01\n#\u30c7\u30a3\u30ba\u30cb\u30fc\u30d7\u30e9\u30b9 \u300e\u30aa\u30d3\uff1d\u30ef\u30f3\u30fb\u30b1\u30ce\u30fc\u30d3\u300f\n\u300e\u30b9\u30bf\u30fc\u30fb\u30a6\u30a9\u30fc\u30ba\u3000\u30a8\u30d4\u30bd\u30fc\u30c9\uff13/\u30b7\u30b9\u306e\u5fa9\u8b90\u300f\u304b\u308910\u5e74\u5f8c\u306e\u4e16\u754c\u304c\u821e\u53f0\u306e\u7269\u8a9e\n5\u670825\u65e516\u6642\u3088\u308a\u914d\u4fe1\u30b9\u30bf\u30fc\u30c8\u2606\n\u8a73\u7d30\u2192https://t.co/CtHiI\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726070810112004",
#         "text": "\u30a2\u30fc\u30b1\u30fc\u30c9\u7248\u306eTMNT\u3042\u3063\u305f\u3089\u6700\u9ad8\u3058\u3083\u306a\u3044\u3067\u3059\u304b\uff01( \u00b4\u2200`)"
#     }
# }
# {
#     "data": {
#         "id": "1501726066628599812",
#         "text": "RT @porquetendencia: \"Viviana Canosa\":\nPor sus declaraciones sobre el #DiaDeLaMujer \nhttps://t.co/Ir1nkBxzOf"
#     }
# }
# {
#     "data": {
#         "id": "1501726066632704004",
#         "text": "\u00b7.\u00b7\u2605 Starter for @electrifiedkira \n\nI stood in the middle of the gas station lot, squinting down at my phone. My signal out here sucked and I was lost. \n\n\"Where... hey, um excuse me? Can you tell me which way the Sheriff's Station is?\" https://t.co/uR7ywANX87"
#     }
# }
# {
#     "data": {
#         "id": "1501726070839590914",
#         "text": "Just a moment of encouragement. \u2764\ufe0f That\u2019s it. That\u2019s the tweet. #ShareKindness"
#     }
# }
# {
#     "data": {
#         "id": "1501726066620059648",
#         "text": "RT @rameshlaus: #EtharkkumThunidhavan 1st Half : @Suriya_offl with his charm and Mass is doing the heavy lifting..\n\nInterval block action i\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726066607599617",
#         "text": "RT @AngelictheVirgo: My attitude when I no longer gaf is disgusting \ud83d\ude2d."
#     }
# }
# {
#     "data": {
#         "id": "1501726070814527496",
#         "text": "RT @JoJoFromJerz: Even trump\u2019s renta-jet was like \u2018get the hell off me!\u2019"
#     }
# }
# {
#     "data": {
#         "id": "1501726070822764544",
#         "text": "\u3044\u3084\u3001\u300c\u3044\u3044\u306d\uff01\u300d\u3058\u3083\u306d\u30fc\u3088\u3002\u4ffa\u306e\u545f\u304d\u306b\u53cd\u5fdc\u3059\u308b\u6687\u304c\u3042\u308b\u306a\u3089\u52c9\u5f37\u3057\u308d\uff01"
#     }
# }
# {
#     "data": {
#         "id": "1501726070801899521",
#         "text": "RT @fxckknaiki: el dormir en el pecho de una persona y escuchar sus latidos es muy AAAAAA"
#     }
# }
# {
#     "data": {
#         "id": "1501726066620387328",
#         "text": "RT @GttT85328595: \u308b\u3063\u304f\u3093\ud83e\udd7a\u2728\u5fc3\u306e\u6e96\u5099\u3092\u305b\u305a\u306b\u898b\u3061\u3083\u3044\u307e\u3057\u305f\ud83e\udd7a\ud83d\udc95\u3068\u3063\u3066\u3082\u304b\u3063\u3053\u3044\u3044\u5199\u771f\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\ud83d\ude47\u200d\u2640\ufe0f\n#JO1 @official_jo1 #\u50d5\u3089\u306e\u5b63\u7bc0 #\u98db\u3079\u308b\u304b\u3089 Dreamer \uff0a Born To Be Wild \uff0a \u7121\u9650\u5927 \uff0a OH-EH\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726066615980036",
#         "text": "@nozochama777 \n\u3054\u53c2\u52a0\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3057\u305f\uff01\n\n\u3010\u62bd\u9078\u306e\u7d50\u679c\u306f\u2026\u3011\n\u306f\u305a\u308c\u3067\u3059\u2026\u3054\u3081\u3093\u306a\u3055\u3044\ud83d\ude22\n\n3/13\u307e\u3067\u6bce\u65e5\u958b\u50ac\u3057\u3066\u3044\u307e\u3059\u306e\u3067\u3001\u660e\u65e5\u3082\u305c\u3072\u30c1\u30e3\u30ec\u30f3\u30b8\u3057\u3066\u304f\u3060\u3055\u3044\u306d\ud83c\udf38\n\n\u25bcDL\u306f\u3053\u3061\u3089\u25bc\nhttps://t.co/IqP7R9lXCe\n\n#\u653e\u7f6e\u5c11\u5973\n#Love\u653e\u7f6e\u5c11\u5973 https://t.co/DmKLgbUtIu"
#     }
# }
# {
#     "data": {
#         "id": "1501726070802100227",
#         "text": "RT @711SEJ: \ud83c\udf81\u30ad\u30e3\u30f3\u30da\u30fc\u30f34\u65e5\u76ee\ud83c\udf81\n\n\uff0f\n\ud83d\udce2 #\u30b5\u30f3\u30c8\u30ea\u30fc\u7fe0\u30b8\u30f3\u30bd\u30fc\u30c0\u7f36 \u304c1\u672c\u7121\u6599\uff01\n\u30d5\u30a9\u30ed\u30fc\uff06RT\u3067\u3001\u671f\u9593\u4e2d\u5408\u8a0820\u4e07\u540d\u69d8\u306b\u4eca\u3059\u3050\u5f53\u305f\u308b\ud83d\udca1\n\uff3c\n\n\u5fdc\u52df\u7de0\u5207\u306f3/20(\u65e5)\u307e\u3067\ud83d\uddd3\ufe0f\n\u4eca\u65e5\u304b\u3089\u30bb\u30d6\u30f3\u2010\u30a4\u30ec\u30d6\u30f3\u3067\u4f7f\u3048\u308b\u3088\u270c\ufe0f\n\n\u5f53\u305f\u308b\u307e\u3067\u6bce\u65e5\u5fdc\u52df\u53ef\u80fd\ud83c\udfaf\n\n\u3010\u5fdc\u52df\u65b9\u6cd5\u3011\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726070814519298",
#         "text": "@lizethselene_ Estoy aqu\u00ed para ti"
#     }
# }
# {
#     "data": {
#         "id": "1501726070835458050",
#         "text": "@GwichBlockchain I Understand how you feel, I have been in this situation before, CONTACT LAWCRACKS ON INSTAGRAM\nhe helped me recover my Account back"
#     }
# }
# {
#     "data": {
#         "id": "1501726070839685122",
#         "text": "RT @fullaheadsdbh: UGM1-SEC3 \u5b6b\u609f\u98ef\uff1a\u5c11\u5e74\u671f UR\n\nhttps://t.co/2V21dHbw8a\n\n#SDBH https://t.co/FzwCu8UPPG"
#     }
# }
# {
#     "data": {
#         "id": "1501726070839595009",
#         "text": "RT @mms_xix: THREAD : Les joueurs du PSG qui m\u00e9ritent une balle de P38 dans le genou https://t.co/rTBPrAbjD3"
#     }
# }
# {
#     "data": {
#         "id": "1501726070806097923",
#         "text": "RT @Melquisedec70: Que como EEUU y OTAN han cometido cr\u00edmenes de guerra contra Irak, Libia y otros pa\u00edses (que millones de personas hemos c\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726070818672642",
#         "text": "Ela acaba com as minhas expectativas"
#     }
# }
# {
#     "data": {
#         "id": "1501726066641195020",
#         "text": "RT @lordivan22: EUA \ud83c\uddfa\ud83c\uddf8: Como a hist\u00f3ria dos ca\u00e7as poloneses escancara a p\u00e9ssima gest\u00e3o (talvez a pior da hist\u00f3ria) da pol\u00edtica exterior da\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726066632806401",
#         "text": "RT @Naty_Patriota: Ya renunci\u00f3 Valenzuela? El futuro ministro de agricultura que se peg\u00f3 el show\u2026 ?\n\n#RenunciaValenzuela"
#     }
# }
# {
#     "data": {
#         "id": "1501726070810284034",
#         "text": "RT @icantstanyu: So, my parents gifted me a puffy vest\u2026they then revealed that they also own the same one! Now, we have a matching family o\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726070818545666",
#         "text": "RT @Doublezeek: \u0e42\u0e14\u0e22\u0e2d\u0e07\u0e17\u0e35\u0e48\u0e41\u0e1b\u0e25\u0e27\u0e48\u0e32\u0e14\u0e35\u0e15\u0e48\u0e2d\u0e43\u0e08\u0e2d\u0e30 https://t.co/7pOmR0G9cl"
#     }
# }
# {
#     "data": {
#         "id": "1501726066632712192",
#         "text": "I'm at SSP Tower in Vadhana, Bangkok https://t.co/R0c9nuPGPg"
#     }
# }
# {
#     "data": {
#         "id": "1501726070823096320",
#         "text": "RT @hannarashi: Renders from my newest MMD! Some spicy Thomato hehe. (Video link is in the reply tweet)\n#GenshinImpact #Ayato #Thoma #thoma\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726066624262144",
#         "text": "@jeonjngk_ookie Goodmorning!! don\u2019t forget to eat your meals, take care always and have a nice day! Ilysm! \ud83d\udc97"
#     }
# }
# {
#     "data": {
#         "id": "1501726066607489026",
#         "text": "I pray that the women in SoKor still have the chance to fight for their rights"
#     }
# }
# {
#     "data": {
#         "id": "1501726070835396609",
# ...
#     }
# }
# {
#     "data": {
#         "id": "1501726297298513920",
#         "text": "@ClubAmerica No registra casos de COVID pero si de pendejez, muertin, bulto Valdez, etc"
#     }
# }
# {
#     "data": {
#         "id": "1501726301526310917",
#         "text": "@eatleech OH MY GOSH \ud83e\udd7a\ud83d\udc97\ud83d\udc97"
#     }
# }
# {
#     "data": {
#         "id": "1501726301488652294",
#         "text": "@ShawnMVotes_ Cronos\nI vote #HappierThanEver for #BestCoverSong at #iHeartAwards"
#     }
# }
# {
#     "data": {
#         "id": "1501726301505220608",
#         "text": "@joelpollak @ScottAdamsSays She will never answer questions as wanted\n\nWhy do people continue to spin daily\n\nWhen they already know she\u2019s not going to answer the questions?\n\nWhy persist????????????"
#     }
# }
# {
#     "data": {
#         "id": "1501726297323544578",
#         "text": "RT @vancik_daii: y ma\u00f1ana quien me va a buscar a la escuela"
#     }
# }
# {
#     "data": {
#         "id": "1501726301526237190",
#         "text": "@MixtUpMixy Oh dear o dear. \ud83d\ude11\ud83d\ude02"
#     }
# }
# {
#     "data": {
#         "id": "1501726301488840704",
#         "text": "RT @cnew888: \u0e40\u0e14\u0e34\u0e19\u0e2b\u0e19\u0e49\u0e32\u0e1b\u0e23\u0e30\u0e40\u0e17\u0e28\u0e44\u0e17\u0e22.. https://t.co/6CTvVOmfwk"
#     }
# }
# {
#     "data": {
#         "id": "1501726301526585346",
#         "text": "RT @laeacademy1023: \u0e43\u0e04\u0e23\u0e2d\u0e48\u0e32\u0e19\u0e01\u0e25\u0e2d\u0e19\u0e44\u0e21\u0e48\u0e40\u0e02\u0e49\u0e32\u0e43\u0e08\u0e1a\u0e49\u0e32\u0e07? \n\n\u2728\u0e40\u0e17\u0e04\u0e19\u0e34\u0e04\u0e01\u0e32\u0e23\u0e2d\u0e48\u0e32\u0e19\u0e01\u0e25\u0e2d\u0e19\u0e20\u0e32\u0e29\u0e32\u0e2d\u0e31\u0e07\u0e01\u0e24\u0e29\u0e41\u0e1a\u0e1a\u0e40\u0e02\u0e49\u0e32\u0e43\u0e08\u0e07\u0e48\u0e32\u0e22\u2728\n\n#GAT #\u0e40\u0e14\u0e47\u0e01\u0e0b\u0e34\u0e48\u0e27 #\u0e01\u0e2a\u0e1e\u0e17 #\u0e01\u0e2a\u0e1e\u0e1765 #\u0e2d\u0e31\u0e01\u0e29\u0e23\u0e08\u0e38\u0e2c\u0e32 https:/\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726301488816128",
#         "text": "@jkscupofmilk @kvsverse"
#     }
# }
# {
#     "data": {
#         "id": "1501726301497008130",
#         "text": "@ysbela6 \ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a\ud83e\udd7a"
#     }
# }
# {
#     "data": {
#         "id": "1501726301505286147",
#         "text": "@ppear_ \u0e2d\u0e49\u0e32\u0e27\u0e27\u0e27"
#     }
# }
# {
#     "data": {
#         "id": "1501726301518184451",
#         "text": "RT @0xSummy: $300 | one winner | 12 hours \n\n\u2022 $150\nMust retweet this, follow @GreatMasquerade &amp; myself and RT their \ud83d\udccc \n\n\u2022 $150\nJoin discord\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726305720676353",
#         "text": "@gmn_cncr \n\u62bd\u9078\u7d50\u679c\u306f\u30fb\u30fb\u30fb\n\n\u304a\u898b\u4e8b\uff5e\ud83c\udf89\ud83c\udf89\ud83c\udf89\ud83c\udf8a\ud83c\udf8a\ud83c\udf8a\n\u300e\u3042\u305f\u308a\ud83c\udfaf\u300f\u3067\u3059\u2728\u2728\u2728\n\n\u3088\u304b\u3063\u305f\u3089\u3001\u5f53\u9078\u5831\u544a\u3084\u3001\u7fe0\u30b8\u30f3\u30bd\u30fc\u30c0\u7f36\u306e\u611f\u60f3\u3092\n #\u30bb\u30d6\u30f3\u3067\u7fe0\u30b8\u30f3\u30bd\u30fc\u30c0\u7f36\u5f53\u305f\u3063\u305f \u3067\u3064\u3076\u3084\u3044\u3066\u307f\u3066\u304f\u3060\u3055\u3044\ud83c\udf81\n\n\u2193\u3092\u30bf\u30c3\u30d7\u3057\u3066\u7121\u6599\u5f15\u63db\u5238\u306e\u53d7\u3051\u53d6\u308a\u306b\u9032\u3093\u3067\u306d\u266a"
#     }
# }
# {
#     "data": {
#         "id": "1501726301493030913",
#         "text": "@shinbunbun_ @ubic_fairy \u304a\u8a95\u751f\u65e5\u304a\u3081\u3067\u3068\u3046\uff01\uff01"
#     }
# }
# {
#     "data": {
#         "id": "1501726301513678849",
#         "text": "@ranjeet1710 \ud83d\ude4f"
#     }
# }
# {
#     "data": {
#         "id": "1501726301488828416",
#         "text": "@MYTASYA4 fb rt pin, thanks"
#     }
# }
# {
#     "data": {
#         "id": "1501726301501071361",
#         "text": "RT @UnaFernandezMas: Hola a todxs\n\nFalleci\u00f3 mi abuela y nos quedaron muchos medicamentos.\nVoy a compartirlos en un hilo y si alguien necesi\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726301493022721",
#         "text": "\u305d\u308c\u3067\u306f\u554f\uff18\u3092ENDU\u524d\u671f\n\n\u554f\uff19\u3092ENDU\u524d\u671f\n\n\u62bd\u9078\u306a\u306e\u3067\uff12\u56de\u5f53\u305f\u308b\u3053\u3068\u306f\u4ed5\u65b9\u304c\u306a\u3044\u3002"
#     }
# }
# {
#     "data": {
#         "id": "1501726301518204928",
#         "text": "\u0e2b\u0e25\u0e48\u0e2d\u0e43\u0e08\u0e2b\u0e32\u0e22\u0e43\u0e08\u0e04\u0e27\u0e48\u0e33\u0e08\u0e23\u0e34\u0e07\u0e46 \u0e42\u0e2d\u0e4a\u0e22 \u0e0a\u0e2d\u0e1a\u0e15\u0e2d\u0e19\u0e1e\u0e34\u0e40\u0e28\u0e29\u0e15\u0e2d\u0e19\u0e19\u0e35\u0e49\u0e2d\u0e30 \u0e44\u0e14\u0e49\u0e40\u0e2b\u0e47\u0e19\u0e04\u0e34\u0e40\u0e2a\u0e30\u0e23\u0e31\u0e1a\u0e1a\u0e17\u0e42\u0e21\u0e40\u0e14\u0e25\u0e1b\u0e31\u0e07\u0e46 \u0e14\u0e35\u0e4a\u0e14\u0e35 https://t.co/GtO32wlguT"
#     }
# }
# {
#     "data": {
#         "id": "1501726301493035010",
#         "text": "RT @pourmerain: \u22b9 RT and re-share are very appreciated! \u22b9\n\n\u22c6 COMMISSION OPEN! \u22c6\n\nhallour everyone! if you\u2019re interested to commissions me,\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726305716518913",
#         "text": "T\u00e1 uma bosta a qualidade de transmiss\u00e3o dos jogos em streams.. seja qual for a plataforma. Espero que essa moda n\u00e3o pegue"
#     }
# }
# {
#     "data": {
#         "id": "1501726305708126212",
#         "text": "Y si me mato \ud83e\udd17"
#     }
# }
# {
#     "data": {
#         "id": "1501726301488496641",
#         "text": "RT @narakkkk7: \u0e40\u0e1b\u0e47\u0e19\u0e2d\u0e30\u0e44\u0e23\u0e4a\u0e44\u0e21\u0e48\u0e2b\u0e27\u0e4a \u0e44\u0e21\u0e48\u0e44\u0e2b\u0e27\u0e4a\u0e41\u0e25\u0e4a\u0e27  #\u0e1a\u0e34\u0e27\u0e01\u0e34\u0e49\u0e19\u0e1b\u0e34\u0e14\u0e41\u0e1c\u0e07 #\u0e1a\u0e34\u0e27\u0e01\u0e34\u0e49\u0e19\u0e1e\u0e35\u0e1e\u0e35 #\u0e1a\u0e34\u0e27\u0e01\u0e34\u0e49\u0e19\u0e04\u0e19\u0e08\u0e23\u0e34\u0e07 #\u0e1a\u0e34\u0e27\u0e01\u0e34\u0e49\u0e19\u0e40\u0e09\u0e25\u0e22\u0e41\u0e25\u0e49\u0e27 https://t.co/XgQocDLFWn"
#     }
# }
# {
#     "data": {
#         "id": "1501726301492690944",
#         "text": "RT @KABUK1YUK1: #\u3075\u306b\u3093\u753b\u3059 https://t.co/gX387F2fiq"
#     }
# }
# {
#     "data": {
#         "id": "1501726305716482051",
#         "text": "RT @ladygreenkirtle: @jk_rowling How can people who start a sentence \"women be quieter\" think they're doing the right thing?"
#     }
# }
# {
#     "data": {
#         "id": "1501726305703841794",
#         "text": "@AnnCoulter He wasn't"
#     }
# }
# {
#     "data": {
#         "id": "1501726305682960386",
#         "text": "RT @ITSCRUSHLOVE: \ud83c\udf9e\ufe0f\ud835\ude7f\ud835\ude70\ud835\ude81\ud835\ude83:-07 https://t.co/87pY4D7Gau"
#     }
# }
# {
#     "data": {
#         "id": "1501726301509468163",
#         "text": "RT @jot_au: @nhlfanforlife @davidbewart @HannaLiubakova Belarus tried to overthrow their Dictator not that long ago, but Putin helped to br\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726305691312132",
#         "text": "RT @iamsashakae: people like molly Mae and Kim just need to be rich and quiet. because getting banged on love island and having a sex tape\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726305691357188",
#         "text": "Proud I did my small part of service, and living amongst so many serving, or in careers assisting the military."
#     }
# }
# {
#     "data": {
#         "id": "1501726305703936004",
#         "text": "RT @ocaradaluva: Gra\u00e7as a Deus pai \ud83d\ude4f\ud83c\udffd https://t.co/pMqNJWithv"
#     }
# }
# {
#     "data": {
#         "id": "1501726301492707328",
#         "text": "RT @711SEJ: \ud83c\udf81\u30ad\u30e3\u30f3\u30da\u30fc\u30f34\u65e5\u76ee\ud83c\udf81\n\n\uff0f\n\ud83d\udce2 #\u30b5\u30f3\u30c8\u30ea\u30fc\u7fe0\u30b8\u30f3\u30bd\u30fc\u30c0\u7f36 \u304c1\u672c\u7121\u6599\uff01\n\u30d5\u30a9\u30ed\u30fc\uff06RT\u3067\u3001\u671f\u9593\u4e2d\u5408\u8a0820\u4e07\u540d\u69d8\u306b\u4eca\u3059\u3050\u5f53\u305f\u308b\ud83d\udca1\n\uff3c\n\n\u5fdc\u52df\u7de0\u5207\u306f3/20(\u65e5)\u307e\u3067\ud83d\uddd3\ufe0f\n\u4eca\u65e5\u304b\u3089\u30bb\u30d6\u30f3\u2010\u30a4\u30ec\u30d6\u30f3\u3067\u4f7f\u3048\u308b\u3088\u270c\ufe0f\n\n\u5f53\u305f\u308b\u307e\u3067\u6bce\u65e5\u5fdc\u52df\u53ef\u80fd\ud83c\udfaf\n\n\u3010\u5fdc\u52df\u65b9\u6cd5\u3011\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726305691262980",
#         "text": "pqp a joy at\u00e9 morta enche o saco na novela"
#     }
# }
# {
#     "data": {
#         "id": "1501726301488844800",
#         "text": "RT @bts_bighit: [#\uc288\uac00\uc0dd\uc77c\u314a\u314b]\n\uc598\ub4e4\uc544(0\uba85) \uc624\ub298\ub3c4 \uace0\uc18c \uc900\ube44\ub410\uc9c0..?\n\uc288\uac00\ub294 ARMY\ub97c \ud83d\udc9c1365244\ud83d\udc9c\nMore photos @ (https://t.co/L05Lpyp99s) \n\n#SUGA #\ubbfc\uc724\uae30 #\uc601\uc6d0\ud788\uc704\ud5d8\ud55c\ub0a8\uc790 #\ubbfc\uc724\uae30\ub97c\uace0\uc18c\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726305687121922",
#         "text": "@SteveReedAP This coach needs firing. His approach of constantly benching to teach a lesson is BS. Let the kid figure it out on the court smh"
#     }
# }
# {
#     "data": {
#         "id": "1501726305699598338",
#         "text": "\u6771\u5317\u672c\u7dda\u3092\u7a81\u3063\u8d70\u308b701\u7cfb\u3001\u6804\u990a\u306e\u584a\u3060\u3068\u601d\u3046"
#     }
# }
# {
#     "data": {
#         "id": "1501726301501399041",
#         "text": "RT @MetaversusNFT: MINT LIVE!!!! \ud83d\ude80\n\nOfficial Mint Link: https://t.co/LS5GuxzHNO\nOfficial Opensea Link: https://t.co/nymu6GNATz\n\nLFG \u2764 https\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726297315168257",
#         "text": "RT @pledis_17: SEVENTEEN POWER OF LOVE : THE MOVIE\n\n\ubd04\uacfc \ud568\uaed8 \ucc3e\uc544\uc628 \uc138\ube10\ud2f4\uc758 \ud2b9\ubcc4\ud55c \uc120\ubb3c\n4\uc6d4 20\uc77c \uadf9\uc7a5\uc5d0\uc11c \ub9cc\ub098\uc694\ud83c\udf81\n\nIn cinemas across the globe April 20 and 23.\nGe\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726305716482050",
#         "text": "RT @edxwpvuhopvt8ok: #sakaryaescort  ki\u015fi beni anlad\u0131. https://t.co/DAkveVdF2Y"
#     }
# }
# {
#     "data": {
#         "id": "1501726305716420615",
#         "text": "RT @etramoi: @hatchedboy \u0e19\u0e35\u0e48\u0e41\u0e1a\u0e1a\u0e07\u0e07\u0e19\u0e30 \u0e1c\u0e1b\u0e04\u0e17\u0e35\u0e48\u0e21\u0e35\u0e25\u0e39\u0e01\u0e41\u0e25\u0e49\u0e27\u0e44\u0e21\u0e48 educate \u0e25\u0e39\u0e01\u0e40\u0e23\u0e37\u0e48\u0e2d\u0e07\u0e40\u0e1e\u0e28\u0e2a\u0e20\u0e32\u0e1e\u0e2b\u0e23\u0e37\u0e2d\u0e2a\u0e34\u0e17\u0e18\u0e34\u0e2a\u0e48\u0e27\u0e19\u0e1a\u0e38\u0e04\u0e04\u0e25\u0e17\u0e35\u0e48\u0e08\u0e30\u0e17\u0e33\u0e2d\u0e30\u0e44\u0e23\u0e2b\u0e23\u0e37\u0e2d\u0e43\u0e2a\u0e48\u0e2d\u0e30\u0e44\u0e23\u0e01\u0e47\u0e44\u0e14\u0e49 \u0e04\u0e34\u0e14\u0e27\u0e48\u0e32\u0e40\u0e1b\u0e47\u0e19\u0e1e\u0e48\u0e2d\u0e41\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1501726305682956297",
#         "text": "\u0645\u0634 \u0631\u062d\u0645\u0627\u0643 \ud83d\udd25 https://t.co/bZNLicSS4h"
#     }
# }
# -----------------------------------------------------------
# KeyboardInterrupt         Traceback (most recent call last)
# <ipython-input-27-af70a55c11f1> in <module>()
#       2 timeout = 0
#       3 while True:
# ----> 4     connect_to_endpoint(url)
#       5     timeout += 1
#       6
#
# <ipython-input-26-830756d6cb01> in connect_to_endpoint(url)
#       2     response = requests.request("GET", url, auth=bearer_oauth, stream=True)
#       3     print(response.status_code)
# ----> 4     for response_line in response.iter_lines():
#       5         if response_line:
#       6             json_response = json.loads(response_line)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     802         pending = None
#     803
# --> 804         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     805
#     806             if pending is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in generate()
#     758             if hasattr(self.raw, 'stream'):
#     759                 try:
# --> 760                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761                         yield chunk
#     762                 except ProtocolError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     596         with self._error_catcher():
#     597             while True:
# --> 598                 self._update_chunk_length()
#     599                 if self.chunk_left == 0:
#     600                     break
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in _update_chunk_length(self)
#     538         if self.chunk_left is not None:
#     539             return
# --> 540         line = self._fp.fp.readline()
#     541         line = line.split(b';', 1)[0]
#     542         try:
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# We will now see how to get tweets based on certain rules using FilteredStream. Tweets are requested from the URL https://api.twitter.com/2/tweets/search/stream/rules <br>
#
# You can adjust the rules by changing sample_rules under the set_rules function. Here the rules are getting tweets with cat and dog text and images. The has: will get tweets that are only associated with images, the tag operator is just a string which can be used at a high level to recognize the rule.<br>
#
# get_stream prints out the tweets retrieved according to the rules from the filtered stream end point.
#
# More details on building rules for the filtered stream endpoint can be found here:
# https://developer.twitter.com/en/docs/twitter-api/tweets/filtered-stream/integrate/build-a-rule

# %%
def get_rules():
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", auth=bearer_oauth
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    return response.json()

def delete_all_rules(rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        auth=bearer_oauth,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    print(json.dumps(response.json()))

    
def set_rules(delete):
    # You can adjust the rules if needed
    sample_rules = [
        {"value": "dog has:images", "tag": "dog pictures"},
        {"value": "cat has:images -grumpy", "tag": "cat pictures"},
    ]
    payload = {"add": sample_rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        auth=bearer_oauth,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))

def get_stream(set):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream", auth=bearer_oauth, stream=True,
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            print(json.dumps(json_response, indent=4, sort_keys=True))

# %% [markdown]
# Once you connect to the FilteredStream endpoint you will keep getting tweets matching the rules through a continuous http streaming connection.

# %%
rules = get_rules()
delete = delete_all_rules(rules)
set = set_rules(delete)
get_stream(set)
# Out:
# {"meta": {"sent": "2022-03-10T01:07:25.550Z", "result_count": 0}}
# {"data": [{"value": "cat has:images -grumpy", "tag": "cat pictures", "id": "1501726386079379457"}, {"value": "dog has:images", "tag": "dog pictures", "id": "1501726386079379456"}], "meta": {"sent": "2022-03-10T01:07:26.903Z", "summary": {"created": 2, "not_created": 0, "valid": 2, "invalid": 0}}}
# 200
# {
#     "data": {
#         "id": "1501726360762404867",
#         "text": "RT @ottersquatter: You fuck with cat boys? https://t.co/sDO1JyBfws"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726360867262468",
#         "text": "RT @INESLAESTRELLA: giving my cat body dysmorphia https://t.co/JteF28ywZg"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726360049389569",
#         "text": "RT @pinokun_1027: \u89aa\u621a\u304c\u6765\u3066\u3001\u76e3\u8996\u4e2d\ud83d\ude05\n\u5e30\u308b\u307e\u3067\u51fa\u3066\u3053\u306a\u3044\u3074\u306e\u304f\u3093\u3067\u3057\u305f\ud83d\udc3e\n\n#\u5b50\u732b #\u4ed4\u732b #\u732b\u00a0 #\u306d\u3053\u00a0 #cat \uff03\u732b\u304c\u3044\u308b\u66ae\u3089\u3057 #\u732b\u597d\u304d\u3055\u3093\u3068\u7e4b\u304c\u308a\u305f\u3044 https://t.co/oKftOEBoCi"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726361580236800",
#         "text": "@MrBeast C\u2019mon in https://t.co/5hZlGeZI2u"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379456",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726361534472193",
#         "text": "RT @TranslatedCats: Waiting to slap the dog 1. https://t.co/6ZssRD7PDU"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379456",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726367150452738",
#         "text": "RT @sFIbAZwsB7j6062: cat https://t.co/rkCrGOLX2i"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726366084988930",
#         "text": "RT @ubco2: #Ukrainian woman carried her old dog for more than 10 miles to cross the border. https://t.co/pQ2FzsX3db"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379456",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726365690830855",
#         "text": "@ladyincrypto @theparktoken theparktoken https://t.co/FLqhUCCuaH"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379456",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726375253712902",
#         "text": "RT @hinako_munchkin: \u3072\u306a\u3001\u8d77\u304d\u305f\uff01\n\n#\u732b #cat https://t.co/Zthc1NnfwZ"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726372812578816",
#         "text": "RT @ubco2: #Ukrainian woman carried her old dog for more than 10 miles to cross the border. https://t.co/pQ2FzsX3db"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379456",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726375312769024",
#         "text": "RT @vkoobuns: yoongi as a cat \u23e4 a birthday thread . https://t.co/uEU42DBkXo"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726372888293386",
#         "text": "RT @ubco2: #Ukrainian woman carried her old dog for more than 10 miles to cross the border. https://t.co/pQ2FzsX3db"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379456",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726375547265026",
#         "text": "RT @MetalSucc: funny cat https://t.co/HrfFOL3Lea"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726375471947782",
#         "text": "RT @TheOnion: Dog Hopes He Doesn\u2019t Get Stuck With Chatty Groomer Again https://t.co/TiTSgELFLt https://t.co/Tzi6K9ZMAa"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379456",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726376419684352",
#         "text": "RT @ubco2: #Ukrainian woman carried her old dog for more than 10 miles to cross the border. https://t.co/pQ2FzsX3db"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379456",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726373949235202",
#         "text": "RT @ubco2: #Ukrainian woman carried her old dog for more than 10 miles to cross the border. https://t.co/pQ2FzsX3db"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379456",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726383453573120",
#         "text": "RT @hinako_munchkin: \u3072\u306a\u3001\u8d77\u304d\u305f\uff01\n\n#\u732b #cat https://t.co/Zthc1NnfwZ"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726388956672006",
#         "text": "RT @Errubato: A Wholesome Dog and a Horny Cat https://t.co/sYsOtAQOJb"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         },
#         {
#             "id": "1501726386079379456",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726389308907520",
#         "text": "RT @philly_chicken: Her: You must be an old dog learning new tricks if you think we fucking\n\nMe: https://t.co/Vx3AwzOfPG"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379456",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726395453607941",
#         "text": "RT @toschie: @CalicoCrew1 @MillieGangs Alley Cat https://t.co/4RGZ64RrSw"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726398272372736",
#         "text": "RT @yama_dog_inu: \u7e2e\u3093\u3060\u304a\u306d https://t.co/w8ki4yCMSH"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379456",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726398037307397",
#         "text": "https://t.co/Xm9iUn9QGZ\n\ud83d\udd52 2h | \ud83c\udf19 Despejado\n\nViento: 3.2 km/h ONO\nRacha: 6.5 km/h\nTemperatura: 11.8 \u00b0C\nHumedad: 80 %\nPresi\u00f3n: 1023.8 hPa\nLluvia: 0.0 mm\n\nhttps://t.co/3B13io0ege\n#Weathercloud https://t.co/mXxtHU3A57"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726400713457665",
#         "text": "RT @bijutsu1: \u300e\u30b4\u30c3\u3061\u3083\u3093\ud83d\ude38Go-chan\u300f(20220307) \ud83c\udfa8\u732b\u3058\u3083\u3089\u3057\u306b\u5922\u4e2d\u3067\u3059\u30cb\u30e3\u30fc\uff01#\u5c3e\u9053 #\u5c3e\u9053\u5e02\u7acb\u7f8e\u8853\u9928 #\u732b #cat https://t.co/0ZmH1ick3v"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726398037200897",
#         "text": "RT @cat_56chan: \uff8e\n\n\uff8e\uff79\uff9e\uff6f https://t.co/v20O0RhNUB"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726399119437827",
#         "text": "RT @GeneralCattis: She hangs out at home with her cat #OnBarbiesDayOff https://t.co/lJe5WtIaS3"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726403045335042",
#         "text": "RT @ubco2: #Ukrainian woman carried her old dog for more than 10 miles to cross the border. https://t.co/pQ2FzsX3db"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379456",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726404723249152",
#         "text": "RT @cat_munzisang: \ub0b4 \ub2e4\ub9ac \uc0ac\uc774\uc5d0\uc11c \uc774\ub7ec\uace0 \uc794\ub300 https://t.co/PM2wAAJmSW"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726410611707907",
#         "text": "RT @Lemon0517ch: \u53ef\u611b\u3044\u9854\u3057\u3066\u305f\u306e\u3067\u76d7\u64ae\u3057\u3061\u3083\u3044\u307e\u3057\u305f\n\u3059\u307f\u307e\u305b\u3093\ud83d\ude40\ud83d\udca6\n\n#\u732b #cat #\u732b\u306e\u5c45\u308b\u66ae\u3089\u3057 https://t.co/c6b0QRwOu7"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726412302008321",
#         "text": "RT @shogetsu9339: Yoongi Cat!\ud83d\udc3e \n\n#HappyBirthdaySUGA #HAPPYSUGADAY #btsfanart #Yoongi https://t.co/JqEN5GBJjO"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726416458883072",
#         "text": "RT @okirakuoki: \u306a\u304b\u3088\u3057\u3002\n\n#cat #\u306d\u3053 #\u732b https://t.co/ttEMdoAZJm"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379457",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1501726418027245569",
#         "text": "\u304b\u308f\u3044\u3044\u3068\u601d\u3063\u305f\u3089\uff32\uff34\u3000#\u53ef\u611b\u3059\u304e\u308b\u72ac https://t.co/hmpzlwAEht"
#     },
#     "matching_rules": [
#         {
#             "id": "1501726386079379456",
#             "tag": "dog pictures"
#         }
#     ]
# }
# -----------------------------------------------------------
# KeyboardInterrupt         Traceback (most recent call last)
# <ipython-input-29-3b567908fb05> in <module>()
#       2 delete = delete_all_rules(rules)
#       3 set = set_rules(delete)
# ----> 4 get_stream(set)
#
# <ipython-input-28-b2304df3543b> in get_stream(set)
#      59             )
#      60         )
# ---> 61     for response_line in response.iter_lines():
#      62         if response_line:
#      63             json_response = json.loads(response_line)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     802         pending = None
#     803
# --> 804         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     805
#     806             if pending is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in generate()
#     758             if hasattr(self.raw, 'stream'):
#     759                 try:
# --> 760                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761                         yield chunk
#     762                 except ProtocolError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     596         with self._error_catcher():
#     597             while True:
# --> 598                 self._update_chunk_length()
#     599                 if self.chunk_left == 0:
#     600                     break
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in _update_chunk_length(self)
#     538         if self.chunk_left is not None:
#     539             return
# --> 540         line = self._fp.fp.readline()
#     541         line = line.split(b';', 1)[0]
#     542         try:
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
